# %%
from statsmodels.tsa.exponential_smoothing.ets import ETSModel
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.metrics import mean_squared_error
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from sklearn.metrics import r2_score as r2_score
from sklearn.metrics import mean_squared_error as mse

from itertools import product

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = [18, 10]

# %% [markdown]
# ## Importing Dataset

# %%
df = pd.read_csv("../../Dataset/Platinum.csv")
df
# Out:
#             Date    Open   Close    High     Low
# 0     2018-01-01   933.5   930.5   933.5   930.5
# 1     2018-01-02   931.0   945.5   946.5   931.0
# 2     2018-01-03   945.0   957.0   961.0   940.5
# 3     2018-01-04   955.0   964.0   966.5   945.0
# 4     2018-01-05   963.0   969.5   970.5   959.5
# ...          ...     ...     ...     ...     ...
# 2339  2024-05-28  1056.0  1059.5  1068.0  1045.0
# 2340  2024-05-29  1061.5  1040.5  1064.0  1036.0
# 2341  2024-05-30  1040.0  1031.5  1043.0  1022.5
# 2342  2024-05-31  1028.0  1038.5  1051.5  1020.0
# 2343  2024-06-01  1038.5  1038.5  1038.5  1038.5
#
# [2344 rows x 5 columns]

# %%
df.dtypes
# Out:
# Date      object
# Open     float64
# Close    float64
# High     float64
# Low      float64
# dtype: object

# %%
df = df[["Close"]]
df.reset_index(drop=True)
# Out:
#        Close
# 0      930.5
# 1      945.5
# 2      957.0
# 3      964.0
# 4      969.5
# ...      ...
# 2339  1059.5
# 2340  1040.5
# 2341  1031.5
# 2342  1038.5
# 2343  1038.5
#
# [2344 rows x 1 columns]

# %%
df.head()
# Out:
#    Close
# 0  930.5
# 1  945.5
# 2  957.0
# 3  964.0
# 4  969.5

# %%
#Đồ thị giá đóng
df.Close.plot(figsize = (10, 7))
plt.ylabel("Platinum price")
plt.show()

# %%
#train test split
train_size = int(0.7 * len(df))

train_df = df[:train_size]
test_df = df[train_size:]

# %%
model = ETSModel(
    train_df['Close'],
    error="mul",
    trend="add",
    seasonal="mul",
    damped_trend=False,
    seasonal_periods=90)

res = model.fit()
print(res.summary())
# Out:
#                                  ETS Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 1640
# Model:                       ETS(MAM)   Log Likelihood               -6550.164
# Date:                Thu, 13 Jun 2024   AIC                          13292.328
# Time:                        11:21:42   BIC                          13810.964
# Sample:                             0   HQIC                         13484.676
#                                - 1640   Scale                            0.000
# Covariance Type:               approx
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# smoothing_level         0.9999      0.023     43.960      0.000       0.955       1.044
# smoothing_trend         0.0004        nan        nan        nan         nan         nan
# smoothing_seasonal   4.644e-05        nan        nan        nan         nan         nan
# initial_level         978.8249        nan        nan        nan         nan         nan
# initial_trend          -0.3703        nan        nan        nan         nan         nan
# initial_seasonal.0      1.0035        nan        nan        nan         nan         nan
# initial_seasonal.1      1.0008        nan        nan        nan         nan         nan
# initial_seasonal.2      1.0108        nan        nan        nan         nan         nan
# initial_seasonal.3      1.0120        nan        nan        nan         nan         nan
# initial_seasonal.4      1.0094        nan        nan        nan         nan         nan
# initial_seasonal.5      1.0208        nan        nan        nan         nan         nan
# initial_seasonal.6      1.0191        nan        nan        nan         nan         nan
# initial_seasonal.7      1.0131        nan        nan        nan         nan         nan
# initial_seasonal.8      1.0107        nan        nan        nan         nan         nan
# initial_seasonal.9      1.0153        nan        nan        nan         nan         nan
# initial_seasonal.10     1.0144        nan        nan        nan         nan         nan
# initial_seasonal.11     1.0160        nan        nan        nan         nan         nan
# initial_seasonal.12     1.0156        nan        nan        nan         nan         nan
# initial_seasonal.13     1.0180        nan        nan        nan         nan         nan
# initial_seasonal.14     1.0182        nan        nan        nan         nan         nan
# initial_seasonal.15     1.0187        nan        nan        nan         nan         nan
# initial_seasonal.16     1.0150        nan        nan        nan         nan         nan
# initial_seasonal.17     1.0173        nan        nan        nan         nan         nan
# initial_seasonal.18     1.0230        nan        nan        nan         nan         nan
# initial_seasonal.19     1.0240        nan        nan        nan         nan         nan
# initial_seasonal.20     1.0206        nan        nan        nan         nan         nan
# initial_seasonal.21     1.0237        nan        nan        nan         nan         nan
# initial_seasonal.22     1.0218        nan        nan        nan         nan         nan
# initial_seasonal.23     1.0209        nan        nan        nan         nan         nan
# initial_seasonal.24     1.0235        nan        nan        nan         nan         nan
# initial_seasonal.25     1.0276        nan        nan        nan         nan         nan
# initial_seasonal.26     1.0276        nan        nan        nan         nan         nan
# initial_seasonal.27     1.0303        nan        nan        nan         nan         nan
# initial_seasonal.28     1.0344        nan        nan        nan         nan         nan
# initial_seasonal.29     1.0339        nan        nan        nan         nan         nan
# initial_seasonal.30     1.0312        nan        nan        nan         nan         nan
# initial_seasonal.31     1.0288        nan        nan        nan         nan         nan
# initial_seasonal.32     1.0226        nan        nan        nan         nan         nan
# initial_seasonal.33     1.0192        nan        nan        nan         nan         nan
# initial_seasonal.34     1.0189        nan        nan        nan         nan         nan
# initial_seasonal.35     1.0143        nan        nan        nan         nan         nan
# initial_seasonal.36     1.0104        nan        nan        nan         nan         nan
# initial_seasonal.37     1.0139        nan        nan        nan         nan         nan
# initial_seasonal.38     1.0120        nan        nan        nan         nan         nan
# initial_seasonal.39     1.0124        nan        nan        nan         nan         nan
# initial_seasonal.40     1.0116        nan        nan        nan         nan         nan
# initial_seasonal.41     1.0113        nan        nan        nan         nan         nan
# initial_seasonal.42     1.0092        nan        nan        nan         nan         nan
# initial_seasonal.43     1.0033        nan        nan        nan         nan         nan
# initial_seasonal.44     1.0078        nan        nan        nan         nan         nan
# initial_seasonal.45     1.0106        nan        nan        nan         nan         nan
# initial_seasonal.46     1.0122        nan        nan        nan         nan         nan
# initial_seasonal.47     1.0130        nan        nan        nan         nan         nan
# initial_seasonal.48     1.0215        nan        nan        nan         nan         nan
# initial_seasonal.49     1.0258        nan        nan        nan         nan         nan
# initial_seasonal.50     1.0285        nan        nan        nan         nan         nan
# initial_seasonal.51     1.0288        nan        nan        nan         nan         nan
# initial_seasonal.52     1.0232        nan        nan        nan         nan         nan
# initial_seasonal.53     1.0245        nan        nan        nan         nan         nan
# initial_seasonal.54     1.0254        nan        nan        nan         nan         nan
# initial_seasonal.55     1.0282        nan        nan        nan         nan         nan
# initial_seasonal.56     1.0242        nan        nan        nan         nan         nan
# initial_seasonal.57     1.0184        nan        nan        nan         nan         nan
# initial_seasonal.58     1.0185        nan        nan        nan         nan         nan
# initial_seasonal.59     1.0142        nan        nan        nan         nan         nan
# initial_seasonal.60     1.0155        nan        nan        nan         nan         nan
# initial_seasonal.61     1.0142        nan        nan        nan         nan         nan
# initial_seasonal.62     1.0100        nan        nan        nan         nan         nan
# initial_seasonal.63     1.0120        nan        nan        nan         nan         nan
# initial_seasonal.64     1.0131        nan        nan        nan         nan         nan
# initial_seasonal.65     1.0131        nan        nan        nan         nan         nan
# initial_seasonal.66     1.0108        nan        nan        nan         nan         nan
# initial_seasonal.67     1.0118        nan        nan        nan         nan         nan
# initial_seasonal.68     1.0113        nan        nan        nan         nan         nan
# initial_seasonal.69     1.0109        nan        nan        nan         nan         nan
# initial_seasonal.70     1.0070        nan        nan        nan         nan         nan
# initial_seasonal.71     1.0089        nan        nan        nan         nan         nan
# initial_seasonal.72     1.0070        nan        nan        nan         nan         nan
# initial_seasonal.73     1.0074        nan        nan        nan         nan         nan
# initial_seasonal.74     1.0058        nan        nan        nan         nan         nan
# initial_seasonal.75     1.0074        nan        nan        nan         nan         nan
# initial_seasonal.76     1.0110        nan        nan        nan         nan         nan
# initial_seasonal.77     1.0119        nan        nan        nan         nan         nan
# initial_seasonal.78     1.0094        nan        nan        nan         nan         nan
# initial_seasonal.79     1.0055        nan        nan        nan         nan         nan
# initial_seasonal.80     1.0014        nan        nan        nan         nan         nan
# initial_seasonal.81     1.0001        nan        nan        nan         nan         nan
# initial_seasonal.82     0.9965        nan        nan        nan         nan         nan
# initial_seasonal.83     0.9960        nan        nan        nan         nan         nan
# initial_seasonal.84     0.9955        nan        nan        nan         nan         nan
# initial_seasonal.85     0.9977        nan        nan        nan         nan         nan
# initial_seasonal.86     1.0044        nan        nan        nan         nan         nan
# initial_seasonal.87     0.9989        nan        nan        nan         nan         nan
# initial_seasonal.88     1.0011        nan        nan        nan         nan         nan
# initial_seasonal.89     1.0000        nan        nan        nan         nan         nan
# ===================================================================================
# Ljung-Box (Q):                      291.94   Jarque-Bera (JB):              4023.73
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.52   Skew:                            -0.27
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.65
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.

# %% [markdown]
# ## FORECASTING

# %%
predicted = res.predict(start = len(train_df), end = len(train_df) + len(test_df) - 1)

# %%
mape = np.mean(np.abs(predicted - test_df['Close'])/np.abs(test_df['Close'])) *100
mse = np.mean(np.square(test_df['Close'] - predicted))
rmse = np.sqrt(mse)

print("Mean Absolute Percentage Error (MAPE):", mape)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Mean Absolute Percentage Error (MAPE): 11.352820079107149
# Mean Squared Error (MSE): 16073.944394971197
# Root Mean Squared Error (RMSE): 126.78306036285446

# %%
# Quá trình tạo index predict 90 ngày tiếp theo
last_index =  df.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+90, step=1)

# Predict the closing prices for the next 90 days
y_next_90_days = res.predict(start = len(df), end = len(df) + 90 - 1)

# Print the predicted closing prices for the next 30 days
print('Predicted closing prices for the next 90 days:')
print(y_next_90_days)
# Out:
# Predicted closing prices for the next 90 days:
# 2344    763.839365
# 2345    761.968640
# 2346    762.102079
# 2347    762.348148
# 2348    764.854874
#            ...
# 2429    751.010072
# 2430    748.151047
# 2431    748.800607
# 2432    746.958911
# 2433    750.802950
# Length: 90, dtype: float64

# %%
predicted
# Out:
# 1640    918.326176
# 1641    918.516809
# 1642    918.721851
# 1643    917.631373
# 1644    919.457064
#            ...
# 2339    769.332167
# 2340    766.408341
# 2341    767.078709
# 2342    765.197004
# 2343    769.139875
# Length: 704, dtype: float64

# %%
dt_train = np.append(train_df, predicted.iloc[0])

# %%
fig, ax = plt.subplots()

plt.plot(pd.RangeIndex(start=0, stop=len(dt_train), step=1), dt_train)
plt.plot(test_df.index, test_df)
plt.plot(test_df.index, predicted)
plt.plot(last_data,y_next_90_days)
plt.plot(pd.RangeIndex(start=last_index, stop=last_index+60, step=1),y_next_90_days[0:60])
plt.plot(pd.RangeIndex(start=last_index, stop=last_index+30, step=1),y_next_90_days[0:30])
plt.legend(['Train', 'Test', 'Predictions', 'Next 90 days Predictions', 'Next 60 days Predictions', 'Next 30 days Predictions'])
plt.show()
