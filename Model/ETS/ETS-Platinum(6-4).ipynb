# %%
from statsmodels.tsa.exponential_smoothing.ets import ETSModel
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.metrics import mean_squared_error
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from sklearn.metrics import r2_score as r2_score
from sklearn.metrics import mean_squared_error as mse

from itertools import product

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = [18, 10]

# %% [markdown]
# ## Importing Dataset

# %%
df = pd.read_csv("../../Dataset/Platinum.csv")
df
# Out:
#         Open   Close    High     Low       Date
# 0      933.5   930.5   933.5   930.5   1/1/2018
# 1      931.0   945.5   946.5   931.0   1/2/2018
# 2      945.0   957.0   961.0   940.5   1/3/2018
# 3      955.0   964.0   966.5   945.0   1/4/2018
# 4      963.0   969.5   970.5   959.5   1/5/2018
# ...      ...     ...     ...     ...        ...
# 2116  1056.0  1059.5  1068.0  1045.0  5/28/2024
# 2117  1061.5  1040.5  1064.0  1036.0  5/29/2024
# 2118  1040.0  1031.5  1043.0  1022.5  5/30/2024
# 2119  1028.0  1038.5  1051.5  1020.0  5/31/2024
# 2120  1038.5  1038.5  1038.5  1038.5   6/1/2024
#
# [2121 rows x 5 columns]

# %%
df.dtypes
# Out:
# Open     float64
# Close    float64
# High     float64
# Low      float64
# Date      object
# dtype: object

# %%
df = df[["Close"]]
df.reset_index(drop=True)
# Out:
#        Close
# 0      930.5
# 1      945.5
# 2      957.0
# 3      964.0
# 4      969.5
# ...      ...
# 2116  1059.5
# 2117  1040.5
# 2118  1031.5
# 2119  1038.5
# 2120  1038.5
#
# [2121 rows x 1 columns]

# %%
df.head()
# Out:
#    Close
# 0  930.5
# 1  945.5
# 2  957.0
# 3  964.0
# 4  969.5

# %%
#Đồ thị giá đóng
df.Close.plot(figsize = (10, 7))
plt.ylabel("Platinum price")
plt.show()

# %%
#train test split
train_size = int(0.6 * len(df))

train_df = df[:train_size]
test_df = df[train_size:]

# %%
model = ETSModel(
    train_df['Close'],
    error="mul",
    trend="add",
    seasonal="mul",
    damped_trend=False,
    seasonal_periods=90)

res = model.fit()
print(res.summary())
# Out:
#                                  ETS Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 1272
# Model:                       ETS(MAM)   Log Likelihood               -5134.130
# Date:                Thu, 06 Jun 2024   AIC                          10460.259
# Time:                        15:03:55   BIC                          10954.500
# Sample:                             0   HQIC                         10645.900
#                                - 1272   Scale                            0.000
# Covariance Type:               approx
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# smoothing_level         0.9999      0.025     39.266      0.000       0.950       1.050
# smoothing_trend      9.999e-05        nan        nan        nan         nan         nan
# smoothing_seasonal    1.37e-05        nan        nan        nan         nan         nan
# initial_level         971.7828        nan        nan        nan         nan         nan
# initial_trend          -0.2265        nan        nan        nan         nan         nan
# initial_seasonal.0      0.9988        nan        nan        nan         nan         nan
# initial_seasonal.1      0.9979        nan        nan        nan         nan         nan
# initial_seasonal.2      0.9992        nan        nan        nan         nan         nan
# initial_seasonal.3      1.0014        nan        nan        nan         nan         nan
# initial_seasonal.4      0.9972        nan        nan        nan         nan         nan
# initial_seasonal.5      0.9977        nan        nan        nan         nan         nan
# initial_seasonal.6      0.9993        nan        nan        nan         nan         nan
# initial_seasonal.7      0.9971        nan        nan        nan         nan         nan
# initial_seasonal.8      0.9918        nan        nan        nan         nan         nan
# initial_seasonal.9      0.9835        nan        nan        nan         nan         nan
# initial_seasonal.10     0.9786        nan        nan        nan         nan         nan
# initial_seasonal.11     0.9810        nan        nan        nan         nan         nan
# initial_seasonal.12     0.9852        nan        nan        nan         nan         nan
# initial_seasonal.13     0.9823        nan        nan        nan         nan         nan
# initial_seasonal.14     0.9852        nan        nan        nan         nan         nan
# initial_seasonal.15     0.9820        nan        nan        nan         nan         nan
# initial_seasonal.16     0.9839        nan        nan        nan         nan         nan
# initial_seasonal.17     0.9851        nan        nan        nan         nan         nan
# initial_seasonal.18     0.9917        nan        nan        nan         nan         nan
# initial_seasonal.19     0.9906        nan        nan        nan         nan         nan
# initial_seasonal.20     0.9867        nan        nan        nan         nan         nan
# initial_seasonal.21     0.9927        nan        nan        nan         nan         nan
# initial_seasonal.22     0.9909        nan        nan        nan         nan         nan
# initial_seasonal.23     0.9928        nan        nan        nan         nan         nan
# initial_seasonal.24     0.9930        nan        nan        nan         nan         nan
# initial_seasonal.25     0.9826        nan        nan        nan         nan         nan
# initial_seasonal.26     0.9745        nan        nan        nan         nan         nan
# initial_seasonal.27     0.9689        nan        nan        nan         nan         nan
# initial_seasonal.28     0.9748        nan        nan        nan         nan         nan
# initial_seasonal.29     0.9642        nan        nan        nan         nan         nan
# initial_seasonal.30     0.9711        nan        nan        nan         nan         nan
# initial_seasonal.31     0.9743        nan        nan        nan         nan         nan
# initial_seasonal.32     0.9763        nan        nan        nan         nan         nan
# initial_seasonal.33     0.9742        nan        nan        nan         nan         nan
# initial_seasonal.34     0.9819        nan        nan        nan         nan         nan
# initial_seasonal.35     0.9773        nan        nan        nan         nan         nan
# initial_seasonal.36     0.9879        nan        nan        nan         nan         nan
# initial_seasonal.37     0.9874        nan        nan        nan         nan         nan
# initial_seasonal.38     0.9908        nan        nan        nan         nan         nan
# initial_seasonal.39     0.9959        nan        nan        nan         nan         nan
# initial_seasonal.40     0.9981        nan        nan        nan         nan         nan
# initial_seasonal.41     1.0020        nan        nan        nan         nan         nan
# initial_seasonal.42     1.0047        nan        nan        nan         nan         nan
# initial_seasonal.43     1.0050        nan        nan        nan         nan         nan
# initial_seasonal.44     1.0079        nan        nan        nan         nan         nan
# initial_seasonal.45     1.0045        nan        nan        nan         nan         nan
# initial_seasonal.46     1.0007        nan        nan        nan         nan         nan
# initial_seasonal.47     1.0040        nan        nan        nan         nan         nan
# initial_seasonal.48     1.0001        nan        nan        nan         nan         nan
# initial_seasonal.49     0.9991        nan        nan        nan         nan         nan
# initial_seasonal.50     0.9971        nan        nan        nan         nan         nan
# initial_seasonal.51     0.9940        nan        nan        nan         nan         nan
# initial_seasonal.52     0.9960        nan        nan        nan         nan         nan
# initial_seasonal.53     0.9991        nan        nan        nan         nan         nan
# initial_seasonal.54     1.0014        nan        nan        nan         nan         nan
# initial_seasonal.55     0.9925        nan        nan        nan         nan         nan
# initial_seasonal.56     0.9945        nan        nan        nan         nan         nan
# initial_seasonal.57     0.9943        nan        nan        nan         nan         nan
# initial_seasonal.58     0.9985        nan        nan        nan         nan         nan
# initial_seasonal.59     0.9946        nan        nan        nan         nan         nan
# initial_seasonal.60     0.9952        nan        nan        nan         nan         nan
# initial_seasonal.61     0.9950        nan        nan        nan         nan         nan
# initial_seasonal.62     0.9951        nan        nan        nan         nan         nan
# initial_seasonal.63     0.9949        nan        nan        nan         nan         nan
# initial_seasonal.64     0.9953        nan        nan        nan         nan         nan
# initial_seasonal.65     0.9935        nan        nan        nan         nan         nan
# initial_seasonal.66     0.9922        nan        nan        nan         nan         nan
# initial_seasonal.67     0.9871        nan        nan        nan         nan         nan
# initial_seasonal.68     0.9874        nan        nan        nan         nan         nan
# initial_seasonal.69     0.9899        nan        nan        nan         nan         nan
# initial_seasonal.70     0.9868        nan        nan        nan         nan         nan
# initial_seasonal.71     0.9843        nan        nan        nan         nan         nan
# initial_seasonal.72     0.9857        nan        nan        nan         nan         nan
# initial_seasonal.73     0.9847        nan        nan        nan         nan         nan
# initial_seasonal.74     0.9778        nan        nan        nan         nan         nan
# initial_seasonal.75     0.9872        nan        nan        nan         nan         nan
# initial_seasonal.76     0.9882        nan        nan        nan         nan         nan
# initial_seasonal.77     0.9861        nan        nan        nan         nan         nan
# initial_seasonal.78     0.9956        nan        nan        nan         nan         nan
# initial_seasonal.79     0.9910        nan        nan        nan         nan         nan
# initial_seasonal.80     0.9936        nan        nan        nan         nan         nan
# initial_seasonal.81     0.9956        nan        nan        nan         nan         nan
# initial_seasonal.82     0.9965        nan        nan        nan         nan         nan
# initial_seasonal.83     0.9975        nan        nan        nan         nan         nan
# initial_seasonal.84     1.0009        nan        nan        nan         nan         nan
# initial_seasonal.85     0.9964        nan        nan        nan         nan         nan
# initial_seasonal.86     0.9940        nan        nan        nan         nan         nan
# initial_seasonal.87     0.9954        nan        nan        nan         nan         nan
# initial_seasonal.88     0.9996        nan        nan        nan         nan         nan
# initial_seasonal.89     1.0000        nan        nan        nan         nan         nan
# ===================================================================================
# Ljung-Box (Q):                      275.52   Jarque-Bera (JB):              2782.74
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.40   Skew:                            -0.37
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.21
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.

# %% [markdown]
# ## FORECASTING

# %%
predicted = res.predict(start = len(train_df), end = len(train_df) + len(test_df) - 1)

# %%
mape = np.mean(np.abs(predicted - test_df['Close'])/np.abs(test_df['Close'])) *100
mse = np.mean(np.square(test_df['Close'] - predicted))
rmse = np.sqrt(mse)

print("Mean Absolute Percentage Error (MAPE):", mape)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Mean Absolute Percentage Error (MAPE): 11.491299868466061
# Mean Squared Error (MSE): 16998.683946854922
# Root Mean Squared Error (RMSE): 130.3790011729455

# %%
# Quá trình tạo index predict 90 ngày tiếp theo
last_index =  df.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+90, step=1)

# Predict the closing prices for the next 90 days
y_next_90_days = res.predict(start = len(df), end = len(df) + 90 - 1)

# Print the predicted closing prices for the next 30 days
print('Predicted closing prices for the next 90 days:')
print(y_next_90_days)
# Out:
# Predicted closing prices for the next 90 days:
# 2121    765.443395
# 2122    762.605443
# 2123    762.827608
# 2124    754.447092
# 2125    757.765899
#            ...
# 2206    759.180517
# 2207    758.752820
# 2208    756.472464
# 2209    753.335348
# 2210    751.523756
# Length: 90, dtype: float64

# %%
predicted
# Out:
# 1272    930.777886
# 1273    932.571767
# 1274    931.477991
# 1275    922.366684
# 1276    928.664937
#            ...
# 2116    777.438199
# 2117    777.005093
# 2118    774.674746
# 2119    771.466993
# 2120    769.616637
# Length: 849, dtype: float64

# %%
dt_train = np.append(train_df, predicted.iloc[0])

# %%
fig, ax = plt.subplots()

plt.plot(pd.RangeIndex(start=0, stop=len(dt_train), step=1), dt_train)
plt.plot(test_df.index, test_df)
plt.plot(test_df.index, predicted)
plt.plot(last_data,y_next_90_days)
plt.plot(pd.RangeIndex(start=last_index, stop=last_index+60, step=1),y_next_90_days[0:60])
plt.plot(pd.RangeIndex(start=last_index, stop=last_index+30, step=1),y_next_90_days[0:30])
plt.legend(['Train', 'Test', 'Predictions', 'Next 90 days Predictions', 'Next 60 days Predictions', 'Next 30 days Predictions'])
plt.show()
