# %%
from statsmodels.tsa.exponential_smoothing.ets import ETSModel
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.metrics import mean_squared_error
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from sklearn.metrics import r2_score as r2_score
from sklearn.metrics import mean_squared_error as mse

from itertools import product

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = [18, 10]

# %% [markdown]
# ## Importing Dataset

# %%
df = pd.read_csv("../../Dataset/Gold.csv")
df
# Out:
#            Date      Open     Close        High        Low
# 0      1/1/2018  1300.760  1313.075  1316.08375  1300.6425
# 1      1/2/2018  1302.910  1316.500  1318.91000  1302.8550
# 2      1/3/2018  1318.375  1318.875  1321.30000  1307.7100
# 3      1/4/2018  1313.105  1327.875  1327.87500  1306.0500
# 4      1/5/2018  1322.050  1319.590  1323.50500  1313.9100
# ...         ...       ...       ...         ...        ...
# 2339  5/28/2024  2352.200  2361.310  2363.46000  2340.4200
# 2340  5/29/2024  2361.390  2339.110  2361.79000  2335.0700
# 2341  5/30/2024  2338.880  2343.380  2351.09000  2323.0300
# 2342  5/31/2024  2343.340  2327.820  2359.58000  2320.6300
# 2343   6/1/2024  2327.820  2327.820  2327.82000  2327.8200
#
# [2344 rows x 5 columns]

# %%
df.dtypes
# Out:
# Date      object
# Open     float64
# Close    float64
# High     float64
# Low      float64
# dtype: object

# %%
df = df[["Close"]]
df.reset_index(drop=True)
# Out:
#          Close
# 0     1313.075
# 1     1316.500
# 2     1318.875
# 3     1327.875
# 4     1319.590
# ...        ...
# 2339  2361.310
# 2340  2339.110
# 2341  2343.380
# 2342  2327.820
# 2343  2327.820
#
# [2344 rows x 1 columns]

# %%
df.head()
# Out:
#       Close
# 0  1313.075
# 1  1316.500
# 2  1318.875
# 3  1327.875
# 4  1319.590

# %%
#Đồ thị giá đóng
df.Close.plot(figsize = (10, 7))
plt.ylabel("Gold price")
plt.show()

# %%
#train test split
train_size = int(0.8 * len(df))

train_df = df[:train_size]
test_df = df[train_size:]

# %%
def optimize_ETS(train_df, param_list):
    results = []
    endog = train_df['Close'].to_numpy()
    
    for order in tqdm_notebook(param_list):
        if order[4] == True and order[1] == None:
            continue
        else:
            model = ETSModel(endog,
                             error = order[0],
                             trend = order[1],
                             seasonal = order[2],
                             damped_trend = order[4],
                             seasonal_periods = order[3]).fit()
              
            aic = model.aic
            mse = model.mse
            results.append([order, aic, mse])

    result_df = pd.DataFrame(results)
    result_df.columns = ["(e, t, s)", "AIC", "MSE"]
    #Sort in ascending order, lower MSE is better
    result_df = result_df.sort_values(by=['MSE', 'AIC'], ascending=True).reset_index(drop=True)
    
    return result_df

# %%
e = ['add', 'mul']
t = ['add', None]
s = ['add', 'mul', None]
p = [7, 30, 90]
d = [True, False]

param_list = list(product(e,t,s,p,d))

# %%
result_df = optimize_ETS(train_df, param_list)
result_df
# Out:
#   0%|          | 0/72 [00:00<?, ?it/s]
#                        (e, t, s)           AIC         MSE
# 0     (mul, add, mul, 90, False)  14842.614782    0.000057
# 1    (mul, None, mul, 90, False)  14839.732806    0.000057
# 2      (mul, add, mul, 90, True)  14845.738836    0.000057
# 3    (mul, None, add, 90, False)  14848.121063    0.000057
# 4     (mul, add, add, 90, False)  14859.096636    0.000057
# 5     (mul, add, mul, 30, False)  14773.997492    0.000059
# 6      (mul, add, add, 30, True)  14775.446086    0.000059
# 7    (mul, None, add, 30, False)  14769.652220    0.000059
# 8      (mul, add, mul, 30, True)  14777.408065    0.000059
# 9    (mul, None, mul, 30, False)  14771.456456    0.000059
# 10     (mul, add, add, 7, False)  14735.286540    0.000059
# 11      (mul, add, add, 7, True)  14738.733640    0.000059
# 12    (mul, None, add, 7, False)  14732.855598    0.000059
# 13      (mul, add, mul, 7, True)  14739.038604    0.000059
# 14    (mul, None, mul, 7, False)  14733.082162    0.000059
# 15    (mul, add, None, 7, False)  14723.131850    0.000059
# 16   (mul, add, None, 30, False)  14723.131850    0.000059
# 17   (mul, add, None, 90, False)  14723.131850    0.000059
# 18     (mul, add, mul, 7, False)  14740.556490    0.000059
# 19    (mul, add, add, 30, False)  14786.763817    0.000059
# 20   (mul, None, None, 7, False)  14720.162161    0.000059
# 21  (mul, None, None, 30, False)  14720.162161    0.000059
# 22  (mul, None, None, 90, False)  14720.162161    0.000059
# 23     (mul, add, None, 7, True)  14726.688828    0.000059
# 24    (mul, add, None, 30, True)  14726.688828    0.000059
# 25    (mul, add, None, 90, True)  14726.688828    0.000059
# 26     (mul, add, add, 90, True)  15030.426540    0.000063
# 27    (add, add, mul, 90, False)  15066.165540  163.205676
# 28     (add, add, mul, 90, True)  15068.690892  163.251411
# 29   (add, None, mul, 90, False)  15062.710817  163.253145
# 30   (add, None, add, 90, False)  15080.578002  164.816247
# 31     (add, add, add, 90, True)  15088.399281  164.976419
# 32    (add, add, mul, 30, False)  15017.010427  169.490209
# 33     (add, add, mul, 30, True)  15019.601506  169.543648
# 34   (add, None, mul, 30, False)  15013.610435  169.544455
# 35     (add, add, add, 30, True)  15022.123990  169.771893
# 36      (add, add, add, 7, True)  14990.083800  171.040601
# 37    (add, None, add, 7, False)  14984.144078  171.046100
# 38      (add, add, mul, 7, True)  14990.192200  171.050490
# 39    (add, None, mul, 7, False)  14984.267180  171.057330
# 40    (add, add, add, 30, False)  15035.613966  171.180242
# 41    (add, add, None, 7, False)  14974.061833  171.221136
# 42   (add, add, None, 30, False)  14974.061833  171.221136
# 43   (add, add, None, 90, False)  14974.061833  171.221136
# 44   (add, None, None, 7, False)  14970.752957  171.284259
# 45  (add, None, None, 30, False)  14970.752957  171.284259
# 46  (add, None, None, 90, False)  14970.752957  171.284259
# 47     (add, add, None, 7, True)  14976.764807  171.285342
# 48    (add, add, None, 30, True)  14976.764807  171.285342
# 49    (add, add, None, 90, True)  14976.764807  171.285342
# 50     (add, add, mul, 7, False)  14991.919918  171.390896
# 51     (add, add, add, 7, False)  15005.095282  172.599477
# 52   (add, None, add, 30, False)  15119.571756  179.401780
# 53    (add, add, add, 90, False)  15253.522001  180.356359

# %%
model = ETSModel(
    train_df['Close'],
    error="mul",
    trend="add",
    seasonal="mul",
    damped_trend=False,
    seasonal_periods=90)

res = model.fit()
print(res.summary())
# Out:
#                                  ETS Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 1875
# Model:                       ETS(MAM)   Log Likelihood               -7325.307
# Date:                Tue, 02 Jul 2024   AIC                          14842.615
# Time:                        16:11:11   BIC                          15374.106
# Sample:                             0   HQIC                         15038.405
#                                - 1875   Scale                            0.000
# Covariance Type:               approx
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# smoothing_level         0.9992      0.023     43.813      0.000       0.955       1.044
# smoothing_trend      9.992e-05        nan        nan        nan         nan         nan
# smoothing_seasonal    7.74e-08        nan        nan        nan         nan         nan
# initial_level        1329.9691        nan        nan        nan         nan         nan
# initial_trend           0.1737      0.058      2.998      0.003       0.060       0.287
# initial_seasonal.0      0.9990        nan        nan        nan         nan         nan
# initial_seasonal.1      0.9980        nan        nan        nan         nan         nan
# initial_seasonal.2      1.0005        nan        nan        nan         nan         nan
# initial_seasonal.3      1.0003        nan        nan        nan         nan         nan
# initial_seasonal.4      0.9999        nan        nan        nan         nan         nan
# initial_seasonal.5      0.9995        nan        nan        nan         nan         nan
# initial_seasonal.6      0.9998        nan        nan        nan         nan         nan
# initial_seasonal.7      0.9971        nan        nan        nan         nan         nan
# initial_seasonal.8      0.9986        nan        nan        nan         nan         nan
# initial_seasonal.9      0.9992        nan        nan        nan         nan         nan
# initial_seasonal.10     0.9986        nan        nan        nan         nan         nan
# initial_seasonal.11     0.9981        nan        nan        nan         nan         nan
# initial_seasonal.12     0.9991        nan        nan        nan         nan         nan
# initial_seasonal.13     0.9998        nan        nan        nan         nan         nan
# initial_seasonal.14     1.0007        nan        nan        nan         nan         nan
# initial_seasonal.15     1.0019        nan        nan        nan         nan         nan
# initial_seasonal.16     1.0015        nan        nan        nan         nan         nan
# initial_seasonal.17     1.0024        nan        nan        nan         nan         nan
# initial_seasonal.18     1.0037        nan        nan        nan         nan         nan
# initial_seasonal.19     1.0063        nan        nan        nan         nan         nan
# initial_seasonal.20     1.0037        nan        nan        nan         nan         nan
# initial_seasonal.21     1.0039        nan        nan        nan         nan         nan
# initial_seasonal.22     1.0038        nan        nan        nan         nan         nan
# initial_seasonal.23     1.0045        nan        nan        nan         nan         nan
# initial_seasonal.24     1.0046        nan        nan        nan         nan         nan
# initial_seasonal.25     1.0049        nan        nan        nan         nan         nan
# initial_seasonal.26     1.0034        nan        nan        nan         nan         nan
# initial_seasonal.27     1.0049        nan        nan        nan         nan         nan
# initial_seasonal.28     1.0041        nan        nan        nan         nan         nan
# initial_seasonal.29     1.0062        nan        nan        nan         nan         nan
# initial_seasonal.30     1.0042        nan        nan        nan         nan         nan
# initial_seasonal.31     1.0028        nan        nan        nan         nan         nan
# initial_seasonal.32     1.0007        nan        nan        nan         nan         nan
# initial_seasonal.33     1.0019        nan        nan        nan         nan         nan
# initial_seasonal.34     1.0022        nan        nan        nan         nan         nan
# initial_seasonal.35     1.0010        nan        nan        nan         nan         nan
# initial_seasonal.36     0.9990        nan        nan        nan         nan         nan
# initial_seasonal.37     1.0029        nan        nan        nan         nan         nan
# initial_seasonal.38     1.0030        nan        nan        nan         nan         nan
# initial_seasonal.39     1.0034        nan        nan        nan         nan         nan
# initial_seasonal.40     1.0042        nan        nan        nan         nan         nan
# initial_seasonal.41     1.0019        nan        nan        nan         nan         nan
# initial_seasonal.42     1.0014        nan        nan        nan         nan         nan
# initial_seasonal.43     1.0021        nan        nan        nan         nan         nan
# initial_seasonal.44     1.0023        nan        nan        nan         nan         nan
# initial_seasonal.45     1.0029        nan        nan        nan         nan         nan
# initial_seasonal.46     1.0029        nan        nan        nan         nan         nan
# initial_seasonal.47     1.0024        nan        nan        nan         nan         nan
# initial_seasonal.48     1.0037        nan        nan        nan         nan         nan
# initial_seasonal.49     1.0051        nan        nan        nan         nan         nan
# initial_seasonal.50     1.0043        nan        nan        nan         nan         nan
# initial_seasonal.51     1.0037        nan        nan        nan         nan         nan
# initial_seasonal.52     1.0021        nan        nan        nan         nan         nan
# initial_seasonal.53     1.0027        nan        nan        nan         nan         nan
# initial_seasonal.54     1.0045        nan        nan        nan         nan         nan
# initial_seasonal.55     1.0048        nan        nan        nan         nan         nan
# initial_seasonal.56     1.0023        nan        nan        nan         nan         nan
# initial_seasonal.57     1.0028        nan        nan        nan         nan         nan
# initial_seasonal.58     1.0028        nan        nan        nan         nan         nan
# initial_seasonal.59     0.9992        nan        nan        nan         nan         nan
# initial_seasonal.60     0.9995        nan        nan        nan         nan         nan
# initial_seasonal.61     0.9984        nan        nan        nan         nan         nan
# initial_seasonal.62     0.9981        nan        nan        nan         nan         nan
# initial_seasonal.63     0.9995        nan        nan        nan         nan         nan
# initial_seasonal.64     1.0008        nan        nan        nan         nan         nan
# initial_seasonal.65     1.0016        nan        nan        nan         nan         nan
# initial_seasonal.66     1.0015        nan        nan        nan         nan         nan
# initial_seasonal.67     1.0019        nan        nan        nan         nan         nan
# initial_seasonal.68     1.0018        nan        nan        nan         nan         nan
# initial_seasonal.69     1.0011        nan        nan        nan         nan         nan
# initial_seasonal.70     1.0002        nan        nan        nan         nan         nan
# initial_seasonal.71     0.9993        nan        nan        nan         nan         nan
# initial_seasonal.72     0.9983        nan        nan        nan         nan         nan
# initial_seasonal.73     1.0009        nan        nan        nan         nan         nan
# initial_seasonal.74     1.0003        nan        nan        nan         nan         nan
# initial_seasonal.75     0.9998        nan        nan        nan         nan         nan
# initial_seasonal.76     0.9993        nan        nan        nan         nan         nan
# initial_seasonal.77     0.9983        nan        nan        nan         nan         nan
# initial_seasonal.78     0.9969        nan        nan        nan         nan         nan
# initial_seasonal.79     0.9966        nan        nan        nan         nan         nan
# initial_seasonal.80     0.9977        nan        nan        nan         nan         nan
# initial_seasonal.81     0.9967        nan        nan        nan         nan         nan
# initial_seasonal.82     0.9989        nan        nan        nan         nan         nan
# initial_seasonal.83     0.9968        nan        nan        nan         nan         nan
# initial_seasonal.84     0.9989        nan        nan        nan         nan         nan
# initial_seasonal.85     0.9983        nan        nan        nan         nan         nan
# initial_seasonal.86     1.0030        nan        nan        nan         nan         nan
# initial_seasonal.87     1.0024        nan        nan        nan         nan         nan
# initial_seasonal.88     1.0016        nan        nan        nan         nan         nan
# initial_seasonal.89     1.0000        nan        nan        nan         nan         nan
# ===================================================================================
# Ljung-Box (Q):                      261.50   Jarque-Bera (JB):              2635.63
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.53   Skew:                            -0.25
# Prob(H) (two-sided):                  0.00   Kurtosis:                         8.79
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.

# %% [markdown]
# ## FORECASTING

# %%
predicted = res.predict(start = len(train_df), end = len(train_df) + len(test_df) - 1)

# %%
mape = np.mean(np.abs(predicted - test_df['Close'])/np.abs(test_df['Close'])) *100
mse = np.mean(np.square(test_df['Close'] - predicted))
rmse = np.sqrt(mse)

print("Mean Absolute Percentage Error (MAPE):", mape)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Mean Absolute Percentage Error (MAPE): 6.904864418703835
# Mean Squared Error (MSE): 36427.41847344618
# Root Mean Squared Error (RMSE): 190.85968268192784

# %%
# Quá trình tạo index predict 90 ngày tiếp theo
last_index =  df.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+90, step=1)

# Predict the closing prices for the next 90 days
y_next_90_days = res.predict(start = len(df), end = len(df) + 90 - 1)

# Print the predicted closing prices for the next 30 days
print('Predicted closing prices for the next 90 days:')
print(y_next_90_days)
# Out:
# Predicted closing prices for the next 90 days:
# 2344    1923.874403
# 2345    1925.266528
# 2346    1921.389306
# 2347    1925.594613
# 2348    1921.537804
#            ...
# 2429    1941.384041
# 2430    1943.554271
# 2431    1946.818440
# 2432    1948.527251
# 2433    1949.896884
# Length: 90, dtype: float64

# %%
dt_train = np.append(train_df, predicted.iloc[0])

# %%
fig, ax = plt.subplots()

plt.plot(pd.RangeIndex(start=0, stop=len(dt_train), step=1), dt_train)
plt.plot(test_df.index, test_df)
plt.plot(test_df.index, predicted)
plt.plot(last_data,y_next_90_days)
plt.plot(pd.RangeIndex(start=last_index, stop=last_index+60, step=1),y_next_90_days[0:60])
plt.plot(pd.RangeIndex(start=last_index, stop=last_index+30, step=1),y_next_90_days[0:30])
plt.legend(['Train', 'Test', 'Predictions', 'Next 90 days Predictions', 'Next 60 days Predictions', 'Next 30 days Predictions'])
plt.show()
