# %%
from statsmodels.tsa.exponential_smoothing.ets import ETSModel
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.metrics import mean_squared_error
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from sklearn.metrics import r2_score as r2_score
from sklearn.metrics import mean_squared_error as mse

from itertools import product

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = [18, 10]

# %% [markdown]
# ## Importing Dataset

# %%
df = pd.read_csv("../../Dataset/Palladium.csv")
df
# Out:
#         Open   Close    High     Low       Date
# 0     1067.5  1067.5  1067.5  1067.5   1/1/2018
# 1     1066.5  1096.0  1099.0  1066.0   1/2/2018
# 2     1095.5  1088.0  1097.0  1084.0   1/3/2018
# 3     1086.5  1102.5  1108.5  1083.5   1/4/2018
# 4     1100.0  1091.5  1103.0  1086.5   1/5/2018
# ...      ...     ...     ...     ...        ...
# 2105   995.5   975.5   997.0   969.5  5/28/2024
# 2106   982.5   968.0   983.0   946.5  5/29/2024
# 2107   957.0   950.5   962.0   932.5  5/30/2024
# 2108   949.5   914.5   956.0   903.5  5/31/2024
# 2109   914.5   914.5   914.5   914.5   6/1/2024
#
# [2110 rows x 5 columns]

# %%
df.dtypes
# Out:
# Open     float64
# Close    float64
# High     float64
# Low      float64
# Date      object
# dtype: object

# %%
df = df[["Close"]]
df.reset_index(drop=True)
# Out:
#        Close
# 0     1067.5
# 1     1096.0
# 2     1088.0
# 3     1102.5
# 4     1091.5
# ...      ...
# 2105   975.5
# 2106   968.0
# 2107   950.5
# 2108   914.5
# 2109   914.5
#
# [2110 rows x 1 columns]

# %%
df.head()
# Out:
#     Close
# 0  1067.5
# 1  1096.0
# 2  1088.0
# 3  1102.5
# 4  1091.5

# %%
#Đồ thị giá đóng
df.Close.plot(figsize = (10, 7))
plt.ylabel("Palladium price")
plt.show()

# %%
#train test split
train_size = int(0.6 * len(df))

train_df = df[:train_size]
test_df = df[train_size:]

# %%
model = ETSModel(
    train_df['Close'],
    error="mul",
    trend="add",
    seasonal="mul",
    damped_trend=False,
    seasonal_periods=90)

res = model.fit()
print(res.summary())
# Out:
#                                  ETS Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 1266
# Model:                       ETS(MAM)   Log Likelihood               -6210.771
# Date:                Thu, 06 Jun 2024   AIC                          12613.542
# Time:                        15:04:13   BIC                          13107.329
# Sample:                             0   HQIC                         12799.056
#                                - 1266   Scale                            0.000
# Covariance Type:               approx
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# smoothing_level         0.9999      0.025     39.423      0.000       0.950       1.050
# smoothing_trend         0.0041      0.004      1.008      0.314      -0.004       0.012
# smoothing_seasonal   1.582e-06        nan        nan        nan         nan         nan
# initial_level        1024.3611     67.450     15.187      0.000     892.162    1156.560
# initial_trend          -1.1267      2.893     -0.389      0.697      -6.796       4.543
# initial_seasonal.0      1.0042      0.066     15.174      0.000       0.875       1.134
# initial_seasonal.1      1.0085      0.067     15.127      0.000       0.878       1.139
# initial_seasonal.2      1.0058      0.067     15.081      0.000       0.875       1.136
# initial_seasonal.3      0.9992      0.066     15.037      0.000       0.869       1.129
# initial_seasonal.4      0.9965      0.066     14.995      0.000       0.866       1.127
# initial_seasonal.5      0.9955      0.067     14.954      0.000       0.865       1.126
# initial_seasonal.6      0.9905      0.066     14.915      0.000       0.860       1.121
# initial_seasonal.7      0.9910      0.067     14.874      0.000       0.860       1.122
# initial_seasonal.8      0.9838      0.066     14.835      0.000       0.854       1.114
# initial_seasonal.9      0.9819      0.066     14.798      0.000       0.852       1.112
# initial_seasonal.10     0.9799      0.066     14.763      0.000       0.850       1.110
# initial_seasonal.11     0.9768      0.066     14.734      0.000       0.847       1.107
# initial_seasonal.12     0.9691      0.066     14.699      0.000       0.840       1.098
# initial_seasonal.13     0.9752      0.066     14.669      0.000       0.845       1.106
# initial_seasonal.14     0.9766      0.067     14.639      0.000       0.846       1.107
# initial_seasonal.15     0.9794      0.067     14.609      0.000       0.848       1.111
# initial_seasonal.16     0.9856      0.068     14.581      0.000       0.853       1.118
# initial_seasonal.17     0.9938      0.068     14.554      0.000       0.860       1.128
# initial_seasonal.18     0.9952      0.068     14.532      0.000       0.861       1.129
# initial_seasonal.19     0.9953      0.069     14.506      0.000       0.861       1.130
# initial_seasonal.20     1.0020      0.069     14.481      0.000       0.866       1.138
# initial_seasonal.21     1.0067      0.070     14.460      0.000       0.870       1.143
# initial_seasonal.22     1.0093      0.070     14.440      0.000       0.872       1.146
# initial_seasonal.23     1.0094      0.070     14.422      0.000       0.872       1.147
# initial_seasonal.24     0.9995      0.069     14.404      0.000       0.864       1.136
# initial_seasonal.25     1.0036      0.070     14.388      0.000       0.867       1.140
# initial_seasonal.26     1.0047      0.070     14.374      0.000       0.868       1.142
# initial_seasonal.27     1.0044      0.070     14.362      0.000       0.867       1.142
# initial_seasonal.28     0.9861      0.069     14.345      0.000       0.851       1.121
# initial_seasonal.29     0.9748      0.068     14.334      0.000       0.842       1.108
# initial_seasonal.30     0.9710      0.068     14.320      0.000       0.838       1.104
# initial_seasonal.31     0.9744      0.068     14.309      0.000       0.841       1.108
# initial_seasonal.32     0.9679      0.068     14.301      0.000       0.835       1.101
# initial_seasonal.33     0.9650      0.068     14.289      0.000       0.833       1.097
# initial_seasonal.34     0.9679      0.068     14.279      0.000       0.835       1.101
# initial_seasonal.35     0.9671      0.068     14.273      0.000       0.834       1.100
# initial_seasonal.36     0.9715      0.068     14.268      0.000       0.838       1.105
# initial_seasonal.37     0.9747      0.068     14.262      0.000       0.841       1.109
# initial_seasonal.38     0.9779      0.069     14.259      0.000       0.843       1.112
# initial_seasonal.39     0.9871      0.069     14.252      0.000       0.851       1.123
# initial_seasonal.40     0.9924      0.070     14.253      0.000       0.856       1.129
# initial_seasonal.41     0.9947      0.070     14.253      0.000       0.858       1.132
# initial_seasonal.42     1.0022      0.070     14.249      0.000       0.864       1.140
# initial_seasonal.43     1.0079      0.071     14.250      0.000       0.869       1.146
# initial_seasonal.44     1.0051      0.071     14.252      0.000       0.867       1.143
# initial_seasonal.45     1.0034      0.070     14.254      0.000       0.865       1.141
# initial_seasonal.46     1.0012      0.070     14.257      0.000       0.864       1.139
# initial_seasonal.47     0.9971      0.070     14.262      0.000       0.860       1.134
# initial_seasonal.48     1.0020      0.070     14.268      0.000       0.864       1.140
# initial_seasonal.49     1.0020      0.070     14.276      0.000       0.864       1.140
# initial_seasonal.50     1.0050      0.070     14.282      0.000       0.867       1.143
# initial_seasonal.51     1.0076      0.071     14.291      0.000       0.869       1.146
# initial_seasonal.52     1.0004      0.070     14.302      0.000       0.863       1.137
# initial_seasonal.53     0.9984      0.070     14.313      0.000       0.862       1.135
# initial_seasonal.54     0.9957      0.070     14.326      0.000       0.860       1.132
# initial_seasonal.55     0.9970      0.070     14.336      0.000       0.861       1.133
# initial_seasonal.56     0.9960      0.069     14.348      0.000       0.860       1.132
# initial_seasonal.57     1.0019      0.070     14.360      0.000       0.865       1.139
# initial_seasonal.58     0.9985      0.069     14.380      0.000       0.862       1.135
# initial_seasonal.59     0.9884      0.069     14.401      0.000       0.854       1.123
# initial_seasonal.60     0.9854      0.068     14.409      0.000       0.851       1.119
# initial_seasonal.61     0.9882      0.069     14.423      0.000       0.854       1.122
# initial_seasonal.62     0.9885      0.068     14.439      0.000       0.854       1.123
# initial_seasonal.63     0.9919      0.069     14.454      0.000       0.857       1.126
# initial_seasonal.64     0.9867      0.068     14.471      0.000       0.853       1.120
# initial_seasonal.65     0.9869      0.068     14.492      0.000       0.853       1.120
# initial_seasonal.66     0.9846      0.068     14.516      0.000       0.852       1.118
# initial_seasonal.67     0.9853      0.068     14.534      0.000       0.852       1.118
# initial_seasonal.68     0.9847      0.068     14.558      0.000       0.852       1.117
# initial_seasonal.69     0.9911      0.068     14.582      0.000       0.858       1.124
# initial_seasonal.70     0.9935      0.068     14.604      0.000       0.860       1.127
# initial_seasonal.71     0.9903      0.068     14.626      0.000       0.858       1.123
# initial_seasonal.72     0.9807      0.067     14.648      0.000       0.849       1.112
# initial_seasonal.73     0.9873      0.067     14.675      0.000       0.855       1.119
# initial_seasonal.74     0.9875      0.067     14.705      0.000       0.856       1.119
# initial_seasonal.75     0.9807      0.067     14.731      0.000       0.850       1.111
# initial_seasonal.76     0.9826      0.067     14.761      0.000       0.852       1.113
# initial_seasonal.77     0.9837      0.067     14.792      0.000       0.853       1.114
# initial_seasonal.78     0.9855      0.066     14.824      0.000       0.855       1.116
# initial_seasonal.79     0.9809      0.066     14.862      0.000       0.852       1.110
# initial_seasonal.80     0.9812      0.066     14.894      0.000       0.852       1.110
# initial_seasonal.81     0.9879      0.066     14.930      0.000       0.858       1.118
# initial_seasonal.82     0.9826      0.066     14.971      0.000       0.854       1.111
# initial_seasonal.83     0.9855      0.066     15.009      0.000       0.857       1.114
# initial_seasonal.84     0.9872      0.066     15.045      0.000       0.859       1.116
# initial_seasonal.85     0.9948      0.066     15.078      0.000       0.866       1.124
# initial_seasonal.86     0.9941      0.066     15.113      0.000       0.865       1.123
# initial_seasonal.87     0.9998      0.066     15.149      0.000       0.870       1.129
# initial_seasonal.88     1.0017      0.066     15.187      0.000       0.872       1.131
# initial_seasonal.89     1.0000      0.066     15.223      0.000       0.871       1.129
# ===================================================================================
# Ljung-Box (Q):                      221.94   Jarque-Bera (JB):             11680.68
# Prob(Q):                              0.02   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.48   Skew:                            -0.46
# Prob(H) (two-sided):                  0.00   Kurtosis:                        17.85
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.

# %% [markdown]
# ## FORECASTING

# %%
predicted = res.predict(start = len(train_df), end = len(train_df) + len(test_df) - 1)

# %%
mape = np.mean(np.abs(predicted - test_df['Close'])/np.abs(test_df['Close'])) *100
mse = np.mean(np.square(test_df['Close'] - predicted))
rmse = np.sqrt(mse)

print("Mean Absolute Percentage Error (MAPE):", mape)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Mean Absolute Percentage Error (MAPE): 80.10531548841772
# Mean Squared Error (MSE): 1314289.7069642765
# Root Mean Squared Error (RMSE): 1146.4247498044851

# %%
# Quá trình tạo index predict 90 ngày tiếp theo
last_index =  df.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+90, step=1)

# Predict the closing prices for the next 90 days
y_next_90_days = res.predict(start = len(df), end = len(df) + 90 - 1)

# Print the predicted closing prices for the next 30 days
print('Predicted closing prices for the next 90 days:')
print(y_next_90_days)
# Out:
# Predicted closing prices for the next 90 days:
# 2110   -653.670815
# 2111   -656.408069
# 2112   -655.862505
# 2113   -661.278526
# 2114   -665.440307
#            ...
# 2195   -877.302723
# 2196   -882.301593
# 2197   -886.772379
# 2198   -895.890344
# 2199   -896.316400
# Length: 90, dtype: float64

# %%
dt_train = np.append(train_df, predicted.iloc[0])

# %%
fig, ax = plt.subplots()

plt.plot(pd.RangeIndex(start=0, stop=len(dt_train), step=1), dt_train)
plt.plot(test_df.index, test_df)
plt.plot(test_df.index, predicted)
plt.plot(last_data,y_next_90_days)
plt.plot(pd.RangeIndex(start=last_index, stop=last_index+60, step=1),y_next_90_days[0:60])
plt.plot(pd.RangeIndex(start=last_index, stop=last_index+30, step=1),y_next_90_days[0:30])
plt.legend(['Train', 'Test', 'Predictions', 'Next 90 days Predictions', 'Next 60 days Predictions', 'Next 30 days Predictions'])
plt.show()
