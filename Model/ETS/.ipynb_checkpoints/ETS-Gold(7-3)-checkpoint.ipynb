# %%
from statsmodels.tsa.exponential_smoothing.ets import ETSModel
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.metrics import mean_squared_error
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from sklearn.metrics import r2_score as r2_score
from sklearn.metrics import mean_squared_error as mse

from itertools import product

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = [18, 10]

# %% [markdown]
# ## Importing Dataset

# %%
df = pd.read_csv("../../Dataset/Gold.csv")
df
# Out:
#           Open     Close      High       Low       Date
# 0     1302.910  1316.500  1318.910  1302.855   1/2/2018
# 1     1318.375  1318.875  1321.300  1307.710   1/3/2018
# 2     1313.105  1327.875  1327.875  1306.050   1/4/2018
# 3     1322.050  1319.590  1323.505  1313.910   1/5/2018
# 4     1321.050  1320.980  1322.210  1315.105   1/8/2018
# ...        ...       ...       ...       ...        ...
# 2110  2352.200  2361.310  2363.460  2340.420  5/28/2024
# 2111  2361.390  2339.110  2361.790  2335.070  5/29/2024
# 2112  2338.880  2343.380  2351.090  2323.030  5/30/2024
# 2113  2343.340  2327.820  2359.580  2320.630  5/31/2024
# 2114  2327.820  2327.820  2327.820  2327.820   6/1/2024
#
# [2115 rows x 5 columns]

# %%
df.dtypes
# Out:
# Open     float64
# Close    float64
# High     float64
# Low      float64
# Date      object
# dtype: object

# %%
df = df[["Close"]]
df.reset_index(drop=True)
# Out:
#          Close
# 0     1316.500
# 1     1318.875
# 2     1327.875
# 3     1319.590
# 4     1320.980
# ...        ...
# 2110  2361.310
# 2111  2339.110
# 2112  2343.380
# 2113  2327.820
# 2114  2327.820
#
# [2115 rows x 1 columns]

# %%
df.head()
# Out:
#       Close
# 0  1316.500
# 1  1318.875
# 2  1327.875
# 3  1319.590
# 4  1320.980

# %%
#Đồ thị giá đóng
df.Close.plot(figsize = (10, 7))
plt.ylabel("Gold price")
plt.show()

# %%
#train test split
train_size = int(0.7 * len(df))

train_df = df[:train_size]
test_df = df[train_size:]

# %%
model = ETSModel(
    train_df['Close'],
    error="mul",
    trend="add",
    seasonal="mul",
    damped_trend=False,
    seasonal_periods=90)

res = model.fit()
print(res.summary())
# Out:
#                                  ETS Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 1480
# Model:                       ETS(MAM)   Log Likelihood               -5873.357
# Date:                Thu, 06 Jun 2024   AIC                          11938.714
# Time:                        15:25:43   BIC                          12447.494
# Sample:                             0   HQIC                         12128.380
#                                - 1480   Scale                            0.000
# Covariance Type:               approx
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# smoothing_level         0.9999      0.026     39.048      0.000       0.950       1.050
# smoothing_trend      9.999e-05        nan        nan        nan         nan         nan
# smoothing_seasonal   1.031e-05        nan        nan        nan         nan         nan
# initial_level        1332.0233        nan        nan        nan         nan         nan
# initial_trend           0.3534      0.340      1.038      0.299      -0.314       1.021
# initial_seasonal.0      1.0009        nan        nan        nan         nan         nan
# initial_seasonal.1      0.9983        nan        nan        nan         nan         nan
# initial_seasonal.2      0.9998        nan        nan        nan         nan         nan
# initial_seasonal.3      0.9984        nan        nan        nan         nan         nan
# initial_seasonal.4      0.9976        nan        nan        nan         nan         nan
# initial_seasonal.5      1.0007        nan        nan        nan         nan         nan
# initial_seasonal.6      1.0030        nan        nan        nan         nan         nan
# initial_seasonal.7      1.0055        nan        nan        nan         nan         nan
# initial_seasonal.8      1.0047        nan        nan        nan         nan         nan
# initial_seasonal.9      1.0064        nan        nan        nan         nan         nan
# initial_seasonal.10     1.0062        nan        nan        nan         nan         nan
# initial_seasonal.11     1.0091        nan        nan        nan         nan         nan
# initial_seasonal.12     1.0097        nan        nan        nan         nan         nan
# initial_seasonal.13     1.0124        nan        nan        nan         nan         nan
# initial_seasonal.14     1.0110        nan        nan        nan         nan         nan
# initial_seasonal.15     1.0095        nan        nan        nan         nan         nan
# initial_seasonal.16     1.0099        nan        nan        nan         nan         nan
# initial_seasonal.17     1.0096        nan        nan        nan         nan         nan
# initial_seasonal.18     1.0091        nan        nan        nan         nan         nan
# initial_seasonal.19     1.0086        nan        nan        nan         nan         nan
# initial_seasonal.20     1.0088        nan        nan        nan         nan         nan
# initial_seasonal.21     1.0078        nan        nan        nan         nan         nan
# initial_seasonal.22     1.0065        nan        nan        nan         nan         nan
# initial_seasonal.23     1.0076        nan        nan        nan         nan         nan
# initial_seasonal.24     1.0055        nan        nan        nan         nan         nan
# initial_seasonal.25     1.0043        nan        nan        nan         nan         nan
# initial_seasonal.26     1.0032        nan        nan        nan         nan         nan
# initial_seasonal.27     1.0024        nan        nan        nan         nan         nan
# initial_seasonal.28     1.0042        nan        nan        nan         nan         nan
# initial_seasonal.29     1.0009        nan        nan        nan         nan         nan
# initial_seasonal.30     1.0019        nan        nan        nan         nan         nan
# initial_seasonal.31     1.0045        nan        nan        nan         nan         nan
# initial_seasonal.32     1.0039        nan        nan        nan         nan         nan
# initial_seasonal.33     1.0036        nan        nan        nan         nan         nan
# initial_seasonal.34     1.0016        nan        nan        nan         nan         nan
# initial_seasonal.35     1.0009        nan        nan        nan         nan         nan
# initial_seasonal.36     0.9992        nan        nan        nan         nan         nan
# initial_seasonal.37     1.0006        nan        nan        nan         nan         nan
# initial_seasonal.38     0.9988        nan        nan        nan         nan         nan
# initial_seasonal.39     0.9983        nan        nan        nan         nan         nan
# initial_seasonal.40     0.9966        nan        nan        nan         nan         nan
# initial_seasonal.41     0.9981        nan        nan        nan         nan         nan
# initial_seasonal.42     0.9973        nan        nan        nan         nan         nan
# initial_seasonal.43     0.9942        nan        nan        nan         nan         nan
# initial_seasonal.44     0.9935        nan        nan        nan         nan         nan
# initial_seasonal.45     0.9952        nan        nan        nan         nan         nan
# initial_seasonal.46     0.9928        nan        nan        nan         nan         nan
# initial_seasonal.47     0.9947        nan        nan        nan         nan         nan
# initial_seasonal.48     0.9966        nan        nan        nan         nan         nan
# initial_seasonal.49     0.9969        nan        nan        nan         nan         nan
# initial_seasonal.50     0.9957        nan        nan        nan         nan         nan
# initial_seasonal.51     0.9975        nan        nan        nan         nan         nan
# initial_seasonal.52     0.9987        nan        nan        nan         nan         nan
# initial_seasonal.53     1.0004        nan        nan        nan         nan         nan
# initial_seasonal.54     1.0006        nan        nan        nan         nan         nan
# initial_seasonal.55     1.0022        nan        nan        nan         nan         nan
# initial_seasonal.56     1.0004        nan        nan        nan         nan         nan
# initial_seasonal.57     0.9979        nan        nan        nan         nan         nan
# initial_seasonal.58     0.9957        nan        nan        nan         nan         nan
# initial_seasonal.59     0.9966        nan        nan        nan         nan         nan
# initial_seasonal.60     0.9936        nan        nan        nan         nan         nan
# initial_seasonal.61     0.9931        nan        nan        nan         nan         nan
# initial_seasonal.62     0.9951        nan        nan        nan         nan         nan
# initial_seasonal.63     0.9951        nan        nan        nan         nan         nan
# initial_seasonal.64     0.9947        nan        nan        nan         nan         nan
# initial_seasonal.65     0.9974        nan        nan        nan         nan         nan
# initial_seasonal.66     0.9955        nan        nan        nan         nan         nan
# initial_seasonal.67     0.9998        nan        nan        nan         nan         nan
# initial_seasonal.68     0.9962        nan        nan        nan         nan         nan
# initial_seasonal.69     0.9970        nan        nan        nan         nan         nan
# initial_seasonal.70     0.9945        nan        nan        nan         nan         nan
# initial_seasonal.71     0.9950        nan        nan        nan         nan         nan
# initial_seasonal.72     0.9984        nan        nan        nan         nan         nan
# initial_seasonal.73     0.9965        nan        nan        nan         nan         nan
# initial_seasonal.74     0.9970        nan        nan        nan         nan         nan
# initial_seasonal.75     0.9980        nan        nan        nan         nan         nan
# initial_seasonal.76     0.9975        nan        nan        nan         nan         nan
# initial_seasonal.77     0.9985        nan        nan        nan         nan         nan
# initial_seasonal.78     0.9983        nan        nan        nan         nan         nan
# initial_seasonal.79     0.9954        nan        nan        nan         nan         nan
# initial_seasonal.80     0.9970        nan        nan        nan         nan         nan
# initial_seasonal.81     0.9957        nan        nan        nan         nan         nan
# initial_seasonal.82     0.9984        nan        nan        nan         nan         nan
# initial_seasonal.83     0.9967        nan        nan        nan         nan         nan
# initial_seasonal.84     0.9969        nan        nan        nan         nan         nan
# initial_seasonal.85     0.9986        nan        nan        nan         nan         nan
# initial_seasonal.86     0.9976        nan        nan        nan         nan         nan
# initial_seasonal.87     0.9980        nan        nan        nan         nan         nan
# initial_seasonal.88     0.9987        nan        nan        nan         nan         nan
# initial_seasonal.89     1.0000        nan        nan        nan         nan         nan
# ===================================================================================
# Ljung-Box (Q):                      242.16   Jarque-Bera (JB):              1634.05
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.40   Skew:                            -0.33
# Prob(H) (two-sided):                  0.00   Kurtosis:                         8.11
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.

# %% [markdown]
# ## FORECASTING

# %%
predicted = res.predict(start = len(train_df), end = len(train_df) + len(test_df) - 1)

# %%
mape = np.mean(np.abs(predicted - test_df['Close'])/np.abs(test_df['Close'])) *100
mse = np.mean(np.square(test_df['Close'] - predicted))
rmse = np.sqrt(mse)

print("Mean Absolute Percentage Error (MAPE):", mape)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Mean Absolute Percentage Error (MAPE): 7.1253057908040125
# Mean Squared Error (MSE): 33615.615881261714
# Root Mean Squared Error (RMSE): 183.34561865848258

# %%
# Quá trình tạo index predict 90 ngày tiếp theo
last_index =  df.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+90, step=1)

# Predict the closing prices for the next 90 days
y_next_90_days = res.predict(start = len(df), end = len(df) + 90 - 1)

# Print the predicted closing prices for the next 30 days
print('Predicted closing prices for the next 90 days:')
print(y_next_90_days)
# Out:
# Predicted closing prices for the next 90 days:
# 2115    1921.795060
# 2116    1923.402722
# 2117    1929.791240
# 2118    1931.664139
# 2119    1929.060242
#            ...
# 2200    1957.148276
# 2201    1956.854433
# 2202    1953.469821
# 2203    1950.118195
# 2204    1954.993475
# Length: 90, dtype: float64

# %%
predicted
# Out:
# 1480    1713.462152
# 1481    1713.247023
# 1482    1710.325800
# 1483    1707.433297
# 1484    1711.743910
#            ...
# 2110    1926.687510
# 2111    1926.403507
# 2112    1923.076819
# 2113    1919.782583
# 2114    1924.587279
# Length: 635, dtype: float64

# %%
dt_train = np.append(train_df, predicted.iloc[0])

# %%
fig, ax = plt.subplots()

plt.plot(pd.RangeIndex(start=0, stop=len(dt_train), step=1), dt_train)
plt.plot(test_df.index, test_df)
plt.plot(test_df.index, predicted)
plt.plot(last_data,y_next_90_days)
plt.plot(pd.RangeIndex(start=last_index, stop=last_index+60, step=1),y_next_90_days[0:60])
plt.plot(pd.RangeIndex(start=last_index, stop=last_index+30, step=1),y_next_90_days[0:30])
plt.legend(['Train', 'Test', 'Predictions', 'Next 90 days Predictions', 'Next 60 days Predictions', 'Next 30 days Predictions'])
plt.show()
