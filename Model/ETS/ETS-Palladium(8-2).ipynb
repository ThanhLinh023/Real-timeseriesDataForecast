# %%
from statsmodels.tsa.exponential_smoothing.ets import ETSModel
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.metrics import mean_squared_error
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from sklearn.metrics import r2_score as r2_score
from sklearn.metrics import mean_squared_error as mse

from itertools import product

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = [18, 10]

# %% [markdown]
# ## Importing Dataset

# %%
df = pd.read_csv("../../Dataset/Palladium.csv")
df
# Out:
#         Open   Close    High     Low       Date
# 0     1067.5  1067.5  1067.5  1067.5   1/1/2018
# 1     1066.5  1096.0  1099.0  1066.0   1/2/2018
# 2     1095.5  1088.0  1097.0  1084.0   1/3/2018
# 3     1086.5  1102.5  1108.5  1083.5   1/4/2018
# 4     1100.0  1091.5  1103.0  1086.5   1/5/2018
# ...      ...     ...     ...     ...        ...
# 2105   995.5   975.5   997.0   969.5  5/28/2024
# 2106   982.5   968.0   983.0   946.5  5/29/2024
# 2107   957.0   950.5   962.0   932.5  5/30/2024
# 2108   949.5   914.5   956.0   903.5  5/31/2024
# 2109   914.5   914.5   914.5   914.5   6/1/2024
#
# [2110 rows x 5 columns]

# %%
df.dtypes
# Out:
# Open     float64
# Close    float64
# High     float64
# Low      float64
# Date      object
# dtype: object

# %%
df = df[["Close"]]
df.reset_index(drop=True)
# Out:
#        Close
# 0     1067.5
# 1     1096.0
# 2     1088.0
# 3     1102.5
# 4     1091.5
# ...      ...
# 2105   975.5
# 2106   968.0
# 2107   950.5
# 2108   914.5
# 2109   914.5
#
# [2110 rows x 1 columns]

# %%
df.head()
# Out:
#     Close
# 0  1067.5
# 1  1096.0
# 2  1088.0
# 3  1102.5
# 4  1091.5

# %%
#Đồ thị giá đóng
df.Close.plot(figsize = (10, 7))
plt.ylabel("Palladium price")
plt.show()

# %%
#train test split
train_size = int(0.8 * len(df))

train_df = df[:train_size]
test_df = df[train_size:]

# %%
model = ETSModel(
    train_df['Close'],
    error="mul",
    trend="add",
    seasonal="mul",
    damped_trend=False,
    seasonal_periods=90)

res = model.fit()
print(res.summary())
# Out:
#                                  ETS Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 1688
# Model:                       ETS(MAM)   Log Likelihood               -8536.571
# Date:                Thu, 06 Jun 2024   AIC                          17265.141
# Time:                        15:04:35   BIC                          17786.546
# Sample:                             0   HQIC                         17458.236
#                                - 1688   Scale                            0.000
# Covariance Type:               approx
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# smoothing_level         0.9999      0.022     45.367      0.000       0.957       1.043
# smoothing_trend         0.0019      0.005      0.354      0.723      -0.009       0.013
# smoothing_seasonal   3.311e-06        nan        nan        nan         nan         nan
# initial_level        1024.3482     80.381     12.744      0.000     866.805    1181.892
# initial_trend          -1.1486      5.250     -0.219      0.827     -11.439       9.142
# initial_seasonal.0      1.0026      0.078     12.818      0.000       0.849       1.156
# initial_seasonal.1      1.0071      0.079     12.795      0.000       0.853       1.161
# initial_seasonal.2      1.0051      0.079     12.772      0.000       0.851       1.159
# initial_seasonal.3      1.0010      0.079     12.749      0.000       0.847       1.155
# initial_seasonal.4      0.9967      0.078     12.729      0.000       0.843       1.150
# initial_seasonal.5      0.9938      0.078     12.710      0.000       0.841       1.147
# initial_seasonal.6      0.9898      0.078     12.692      0.000       0.837       1.143
# initial_seasonal.7      0.9929      0.078     12.675      0.000       0.839       1.146
# initial_seasonal.8      0.9893      0.078     12.658      0.000       0.836       1.142
# initial_seasonal.9      0.9869      0.078     12.643      0.000       0.834       1.140
# initial_seasonal.10     0.9905      0.078     12.628      0.000       0.837       1.144
# initial_seasonal.11     0.9900      0.078     12.613      0.000       0.836       1.144
# initial_seasonal.12     0.9870      0.078     12.603      0.000       0.834       1.141
# initial_seasonal.13     0.9923      0.079     12.594      0.000       0.838       1.147
# initial_seasonal.14     0.9943      0.079     12.583      0.000       0.839       1.149
# initial_seasonal.15     0.9962      0.079     12.574      0.000       0.841       1.152
# initial_seasonal.16     0.9979      0.079     12.566      0.000       0.842       1.154
# initial_seasonal.17     0.9986      0.080     12.557      0.000       0.843       1.154
# initial_seasonal.18     0.9963      0.079     12.548      0.000       0.841       1.152
# initial_seasonal.19     0.9927      0.079     12.536      0.000       0.838       1.148
# initial_seasonal.20     0.9979      0.080     12.525      0.000       0.842       1.154
# initial_seasonal.21     0.9990      0.080     12.516      0.000       0.843       1.155
# initial_seasonal.22     1.0038      0.080     12.506      0.000       0.847       1.161
# initial_seasonal.23     1.0071      0.081     12.494      0.000       0.849       1.165
# initial_seasonal.24     1.0020      0.080     12.482      0.000       0.845       1.159
# initial_seasonal.25     1.0054      0.081     12.470      0.000       0.847       1.163
# initial_seasonal.26     1.0011      0.080     12.456      0.000       0.844       1.159
# initial_seasonal.27     0.9977      0.080     12.441      0.000       0.840       1.155
# initial_seasonal.28     0.9851      0.079     12.432      0.000       0.830       1.140
# initial_seasonal.29     0.9758      0.079     12.422      0.000       0.822       1.130
# initial_seasonal.30     0.9728      0.078     12.411      0.000       0.819       1.126
# initial_seasonal.31     0.9752      0.079     12.399      0.000       0.821       1.129
# initial_seasonal.32     0.9703      0.078     12.392      0.000       0.817       1.124
# initial_seasonal.33     0.9684      0.078     12.382      0.000       0.815       1.122
# initial_seasonal.34     0.9733      0.079     12.373      0.000       0.819       1.127
# initial_seasonal.35     0.9758      0.079     12.365      0.000       0.821       1.131
# initial_seasonal.36     0.9793      0.079     12.359      0.000       0.824       1.135
# initial_seasonal.37     0.9819      0.079     12.351      0.000       0.826       1.138
# initial_seasonal.38     0.9846      0.080     12.345      0.000       0.828       1.141
# initial_seasonal.39     0.9932      0.081     12.336      0.000       0.835       1.151
# initial_seasonal.40     0.9976      0.081     12.330      0.000       0.839       1.156
# initial_seasonal.41     1.0015      0.081     12.326      0.000       0.842       1.161
# initial_seasonal.42     1.0123      0.082     12.325      0.000       0.851       1.173
# initial_seasonal.43     1.0191      0.083     12.322      0.000       0.857       1.181
# initial_seasonal.44     1.0199      0.083     12.319      0.000       0.858       1.182
# initial_seasonal.45     1.0140      0.082     12.317      0.000       0.853       1.175
# initial_seasonal.46     1.0088      0.082     12.314      0.000       0.848       1.169
# initial_seasonal.47     1.0074      0.082     12.312      0.000       0.847       1.168
# initial_seasonal.48     1.0086      0.082     12.313      0.000       0.848       1.169
# initial_seasonal.49     1.0045      0.082     12.313      0.000       0.845       1.164
# initial_seasonal.50     1.0071      0.082     12.310      0.000       0.847       1.167
# initial_seasonal.51     1.0079      0.082     12.312      0.000       0.847       1.168
# initial_seasonal.52     1.0051      0.082     12.315      0.000       0.845       1.165
# initial_seasonal.53     1.0045      0.082     12.317      0.000       0.845       1.164
# initial_seasonal.54     1.0009      0.081     12.320      0.000       0.842       1.160
# initial_seasonal.55     1.0011      0.081     12.323      0.000       0.842       1.160
# initial_seasonal.56     1.0002      0.081     12.328      0.000       0.841       1.159
# initial_seasonal.57     1.0042      0.081     12.331      0.000       0.845       1.164
# initial_seasonal.58     1.0045      0.081     12.335      0.000       0.845       1.164
# initial_seasonal.59     0.9980      0.081     12.344      0.000       0.839       1.156
# initial_seasonal.60     0.9949      0.081     12.351      0.000       0.837       1.153
# initial_seasonal.61     0.9998      0.081     12.358      0.000       0.841       1.158
# initial_seasonal.62     1.0034      0.081     12.367      0.000       0.844       1.162
# initial_seasonal.63     1.0049      0.081     12.377      0.000       0.846       1.164
# initial_seasonal.64     0.9982      0.081     12.384      0.000       0.840       1.156
# initial_seasonal.65     0.9957      0.080     12.394      0.000       0.838       1.153
# initial_seasonal.66     0.9909      0.080     12.406      0.000       0.834       1.147
# initial_seasonal.67     0.9915      0.080     12.418      0.000       0.835       1.148
# initial_seasonal.68     0.9887      0.080     12.430      0.000       0.833       1.145
# initial_seasonal.69     0.9961      0.080     12.443      0.000       0.839       1.153
# initial_seasonal.70     1.0000      0.080     12.457      0.000       0.843       1.157
# initial_seasonal.71     1.0055      0.081     12.475      0.000       0.848       1.163
# initial_seasonal.72     1.0013      0.080     12.490      0.000       0.844       1.158
# initial_seasonal.73     1.0110      0.081     12.504      0.000       0.853       1.169
# initial_seasonal.74     1.0113      0.081     12.518      0.000       0.853       1.170
# initial_seasonal.75     1.0015      0.080     12.537      0.000       0.845       1.158
# initial_seasonal.76     0.9989      0.080     12.555      0.000       0.843       1.155
# initial_seasonal.77     0.9944      0.079     12.573      0.000       0.839       1.149
# initial_seasonal.78     0.9955      0.079     12.588      0.000       0.840       1.150
# initial_seasonal.79     0.9930      0.079     12.605      0.000       0.839       1.147
# initial_seasonal.80     0.9959      0.079     12.626      0.000       0.841       1.150
# initial_seasonal.81     1.0022      0.079     12.644      0.000       0.847       1.158
# initial_seasonal.82     0.9959      0.079     12.670      0.000       0.842       1.150
# initial_seasonal.83     0.9926      0.078     12.693      0.000       0.839       1.146
# initial_seasonal.84     0.9882      0.078     12.711      0.000       0.836       1.141
# initial_seasonal.85     0.9963      0.078     12.734      0.000       0.843       1.150
# initial_seasonal.86     0.9976      0.078     12.763      0.000       0.844       1.151
# initial_seasonal.87     1.0048      0.079     12.788      0.000       0.851       1.159
# initial_seasonal.88     1.0021      0.078     12.818      0.000       0.849       1.155
# initial_seasonal.89     1.0000      0.078     12.845      0.000       0.847       1.153
# ===================================================================================
# Ljung-Box (Q):                      244.98   Jarque-Bera (JB):              5829.24
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.94   Skew:                            -0.32
# Prob(H) (two-sided):                  0.00   Kurtosis:                        12.08
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.

# %% [markdown]
# ## FORECASTING

# %%
predicted = res.predict(start = len(train_df), end = len(train_df) + len(test_df) - 1)

# %%
mape = np.mean(np.abs(predicted - test_df['Close'])/np.abs(test_df['Close'])) *100
mse = np.mean(np.square(test_df['Close'] - predicted))
rmse = np.sqrt(mse)

print("Mean Absolute Percentage Error (MAPE):", mape)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Mean Absolute Percentage Error (MAPE): 5.958005016262574
# Mean Squared Error (MSE): 7594.965257195031
# Root Mean Squared Error (RMSE): 87.1490978564611

# %%
# Quá trình tạo index predict 90 ngày tiếp theo
last_index =  df.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+90, step=1)

# Predict the closing prices for the next 90 days
y_next_90_days = res.predict(start = len(df), end = len(df) + 90 - 1)

# Print the predicted closing prices for the next 30 days
print('Predicted closing prices for the next 90 days:')
print(y_next_90_days)
# Out:
# Predicted closing prices for the next 90 days:
# 2110    936.895792
# 2111    939.572165
# 2112    937.241713
# 2113    937.337439
# 2114    941.009368
#            ...
# 2195    835.209506
# 2196    837.008904
# 2197    836.346370
# 2198    837.577043
# 2199    835.722999
# Length: 90, dtype: float64

# %%
dt_train = np.append(train_df, predicted.iloc[0])

# %%
fig, ax = plt.subplots()

plt.plot(pd.RangeIndex(start=0, stop=len(dt_train), step=1), dt_train)
plt.plot(test_df.index, test_df)
plt.plot(test_df.index, predicted)
plt.plot(last_data,y_next_90_days)
plt.plot(pd.RangeIndex(start=last_index, stop=last_index+60, step=1),y_next_90_days[0:60])
plt.plot(pd.RangeIndex(start=last_index, stop=last_index+30, step=1),y_next_90_days[0:30])
plt.legend(['Train', 'Test', 'Predictions', 'Next 90 days Predictions', 'Next 60 days Predictions', 'Next 30 days Predictions'])
plt.show()
