# %%
from statsmodels.tsa.exponential_smoothing.ets import ETSModel
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.metrics import mean_squared_error
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from sklearn.metrics import r2_score as r2_score
from sklearn.metrics import mean_squared_error as mse

from itertools import product

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = [18, 10]

# %% [markdown]
# ## Importing Dataset

# %%
df = pd.read_csv("../../Dataset/Palladium.csv")
df
# Out:
#             Date    Open   Close    High     Low
# 0     2018-01-01  1067.5  1067.5  1067.5  1067.5
# 1     2018-01-02  1066.5  1096.0  1099.0  1066.0
# 2     2018-01-03  1095.5  1088.0  1097.0  1084.0
# 3     2018-01-04  1086.5  1102.5  1108.5  1083.5
# 4     2018-01-05  1100.0  1091.5  1103.0  1086.5
# ...          ...     ...     ...     ...     ...
# 2339  2024-05-28   995.5   975.5   997.0   969.5
# 2340  2024-05-29   982.5   968.0   983.0   946.5
# 2341  2024-05-30   957.0   950.5   962.0   932.5
# 2342  2024-05-31   949.5   914.5   956.0   903.5
# 2343  2024-06-01   914.5   914.5   914.5   914.5
#
# [2344 rows x 5 columns]

# %%
df.dtypes
# Out:
# Date      object
# Open     float64
# Close    float64
# High     float64
# Low      float64
# dtype: object

# %%
df = df[["Close"]]
df.reset_index(drop=True)
# Out:
#        Close
# 0     1067.5
# 1     1096.0
# 2     1088.0
# 3     1102.5
# 4     1091.5
# ...      ...
# 2339   975.5
# 2340   968.0
# 2341   950.5
# 2342   914.5
# 2343   914.5
#
# [2344 rows x 1 columns]

# %%
df.head()
# Out:
#     Close
# 0  1067.5
# 1  1096.0
# 2  1088.0
# 3  1102.5
# 4  1091.5

# %%
#Đồ thị giá đóng
df.Close.plot(figsize = (10, 7))
plt.ylabel("Palladium price")
plt.show()

# %%
#train test split
train_size = int(0.8 * len(df))

train_df = df[:train_size]
test_df = df[train_size:]

# %%
model = ETSModel(
    train_df['Close'],
    error="mul",
    trend="add",
    seasonal="mul",
    damped_trend=False,
    seasonal_periods=90)

res = model.fit()
print(res.summary())
# Out:
#                                  ETS Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 1875
# Model:                       ETS(MAM)   Log Likelihood               -9352.105
# Date:                Thu, 13 Jun 2024   AIC                          18896.209
# Time:                        11:21:35   BIC                          19427.700
# Sample:                             0   HQIC                         19092.000
#                                - 1875   Scale                            0.000
# Covariance Type:               approx
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# smoothing_level         0.9999      0.021     47.466      0.000       0.959       1.041
# smoothing_trend         0.0026      0.005      0.523      0.601      -0.007       0.012
# smoothing_seasonal    1.32e-06        nan        nan        nan         nan         nan
# initial_level        1037.7130     96.039     10.805      0.000     849.480    1225.946
# initial_trend          -1.8947      5.125     -0.370      0.712     -11.939       8.149
# initial_seasonal.0      1.0047      0.092     10.867      0.000       0.823       1.186
# initial_seasonal.1      1.0092      0.093     10.858      0.000       0.827       1.191
# initial_seasonal.2      1.0130      0.093     10.846      0.000       0.830       1.196
# initial_seasonal.3      1.0130      0.093     10.839      0.000       0.830       1.196
# initial_seasonal.4      1.0144      0.094     10.830      0.000       0.831       1.198
# initial_seasonal.5      1.0198      0.094     10.820      0.000       0.835       1.205
# initial_seasonal.6      1.0220      0.095     10.812      0.000       0.837       1.207
# initial_seasonal.7      1.0187      0.094     10.804      0.000       0.834       1.204
# initial_seasonal.8      1.0193      0.094     10.797      0.000       0.834       1.204
# initial_seasonal.9      1.0253      0.095     10.788      0.000       0.839       1.212
# initial_seasonal.10     1.0272      0.095     10.781      0.000       0.840       1.214
# initial_seasonal.11     1.0273      0.095     10.775      0.000       0.840       1.214
# initial_seasonal.12     1.0245      0.095     10.769      0.000       0.838       1.211
# initial_seasonal.13     1.0202      0.095     10.763      0.000       0.834       1.206
# initial_seasonal.14     1.0182      0.095     10.757      0.000       0.833       1.204
# initial_seasonal.15     1.0237      0.095     10.753      0.000       0.837       1.210
# initial_seasonal.16     1.0216      0.095     10.744      0.000       0.835       1.208
# initial_seasonal.17     1.0245      0.095     10.736      0.000       0.837       1.212
# initial_seasonal.18     1.0268      0.096     10.727      0.000       0.839       1.214
# initial_seasonal.19     1.0307      0.096     10.719      0.000       0.842       1.219
# initial_seasonal.20     1.0275      0.096     10.712      0.000       0.840       1.216
# initial_seasonal.21     1.0300      0.096     10.705      0.000       0.841       1.219
# initial_seasonal.22     1.0355      0.097     10.696      0.000       0.846       1.225
# initial_seasonal.23     1.0354      0.097     10.690      0.000       0.846       1.225
# initial_seasonal.24     1.0364      0.097     10.683      0.000       0.846       1.227
# initial_seasonal.25     1.0347      0.097     10.678      0.000       0.845       1.225
# initial_seasonal.26     1.0363      0.097     10.671      0.000       0.846       1.227
# initial_seasonal.27     1.0355      0.097     10.665      0.000       0.845       1.226
# initial_seasonal.28     1.0379      0.097     10.660      0.000       0.847       1.229
# initial_seasonal.29     1.0370      0.097     10.655      0.000       0.846       1.228
# initial_seasonal.30     1.0283      0.097     10.651      0.000       0.839       1.218
# initial_seasonal.31     1.0271      0.096     10.649      0.000       0.838       1.216
# initial_seasonal.32     1.0206      0.096     10.646      0.000       0.833       1.209
# initial_seasonal.33     1.0193      0.096     10.642      0.000       0.832       1.207
# initial_seasonal.34     1.0236      0.096     10.638      0.000       0.835       1.212
# initial_seasonal.35     1.0227      0.096     10.635      0.000       0.834       1.211
# initial_seasonal.36     1.0251      0.096     10.632      0.000       0.836       1.214
# initial_seasonal.37     1.0272      0.097     10.628      0.000       0.838       1.217
# initial_seasonal.38     1.0292      0.097     10.627      0.000       0.839       1.219
# initial_seasonal.39     1.0325      0.097     10.625      0.000       0.842       1.223
# initial_seasonal.40     1.0288      0.097     10.623      0.000       0.839       1.219
# initial_seasonal.41     1.0219      0.096     10.621      0.000       0.833       1.210
# initial_seasonal.42     1.0190      0.096     10.620      0.000       0.831       1.207
# initial_seasonal.43     1.0116      0.095     10.618      0.000       0.825       1.198
# initial_seasonal.44     1.0118      0.095     10.617      0.000       0.825       1.199
# initial_seasonal.45     1.0183      0.096     10.616      0.000       0.830       1.206
# initial_seasonal.46     1.0167      0.096     10.617      0.000       0.829       1.204
# initial_seasonal.47     1.0118      0.095     10.617      0.000       0.825       1.199
# initial_seasonal.48     1.0151      0.096     10.617      0.000       0.828       1.202
# initial_seasonal.49     1.0204      0.096     10.618      0.000       0.832       1.209
# initial_seasonal.50     1.0201      0.096     10.619      0.000       0.832       1.208
# initial_seasonal.51     1.0193      0.096     10.619      0.000       0.831       1.207
# initial_seasonal.52     1.0159      0.096     10.622      0.000       0.828       1.203
# initial_seasonal.53     1.0220      0.096     10.625      0.000       0.833       1.210
# initial_seasonal.54     1.0269      0.097     10.627      0.000       0.838       1.216
# initial_seasonal.55     1.0317      0.097     10.631      0.000       0.841       1.222
# initial_seasonal.56     1.0305      0.097     10.634      0.000       0.841       1.220
# initial_seasonal.57     1.0372      0.098     10.637      0.000       0.846       1.228
# initial_seasonal.58     1.0415      0.098     10.640      0.000       0.850       1.233
# initial_seasonal.59     1.0397      0.098     10.642      0.000       0.848       1.231
# initial_seasonal.60     1.0479      0.098     10.647      0.000       0.855       1.241
# initial_seasonal.61     1.0397      0.098     10.654      0.000       0.848       1.231
# initial_seasonal.62     1.0342      0.097     10.658      0.000       0.844       1.224
# initial_seasonal.63     1.0298      0.097     10.664      0.000       0.841       1.219
# initial_seasonal.64     1.0283      0.096     10.669      0.000       0.839       1.217
# initial_seasonal.65     1.0293      0.096     10.674      0.000       0.840       1.218
# initial_seasonal.66     1.0270      0.096     10.680      0.000       0.839       1.215
# initial_seasonal.67     1.0250      0.096     10.686      0.000       0.837       1.213
# initial_seasonal.68     1.0270      0.096     10.693      0.000       0.839       1.215
# initial_seasonal.69     1.0214      0.095     10.700      0.000       0.834       1.209
# initial_seasonal.70     1.0149      0.095     10.707      0.000       0.829       1.201
# initial_seasonal.71     1.0173      0.095     10.714      0.000       0.831       1.203
# initial_seasonal.72     1.0173      0.095     10.721      0.000       0.831       1.203
# initial_seasonal.73     1.0156      0.095     10.728      0.000       0.830       1.201
# initial_seasonal.74     1.0172      0.095     10.735      0.000       0.831       1.203
# initial_seasonal.75     1.0154      0.095     10.744      0.000       0.830       1.201
# initial_seasonal.76     1.0162      0.095     10.752      0.000       0.831       1.201
# initial_seasonal.77     1.0230      0.095     10.759      0.000       0.837       1.209
# initial_seasonal.78     1.0158      0.094     10.766      0.000       0.831       1.201
# initial_seasonal.79     1.0138      0.094     10.773      0.000       0.829       1.198
# initial_seasonal.80     1.0089      0.094     10.781      0.000       0.825       1.192
# initial_seasonal.81     1.0078      0.093     10.791      0.000       0.825       1.191
# initial_seasonal.82     1.0138      0.094     10.800      0.000       0.830       1.198
# initial_seasonal.83     1.0080      0.093     10.809      0.000       0.825       1.191
# initial_seasonal.84     1.0076      0.093     10.817      0.000       0.825       1.190
# initial_seasonal.85     1.0053      0.093     10.825      0.000       0.823       1.187
# initial_seasonal.86     1.0001      0.092     10.840      0.000       0.819       1.181
# initial_seasonal.87     1.0052      0.093     10.851      0.000       0.824       1.187
# initial_seasonal.88     1.0012      0.092     10.866      0.000       0.821       1.182
# initial_seasonal.89     1.0000      0.092     10.879      0.000       0.820       1.180
# ===================================================================================
# Ljung-Box (Q):                      248.15   Jarque-Bera (JB):             11153.49
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.10   Skew:                            -0.26
# Prob(H) (two-sided):                  0.00   Kurtosis:                        14.94
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.

# %% [markdown]
# ## FORECASTING

# %%
predicted = res.predict(start = len(train_df), end = len(train_df) + len(test_df) - 1)

# %%
mape = np.mean(np.abs(predicted - test_df['Close'])/np.abs(test_df['Close'])) *100
mse = np.mean(np.square(test_df['Close'] - predicted))
rmse = np.sqrt(mse)

print("Mean Absolute Percentage Error (MAPE):", mape)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Mean Absolute Percentage Error (MAPE): 5.857286668719105
# Mean Squared Error (MSE): 7191.420354715452
# Root Mean Squared Error (RMSE): 84.802242627866

# %%
# Quá trình tạo index predict 90 ngày tiếp theo
last_index =  df.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+90, step=1)

# Predict the closing prices for the next 90 days
y_next_90_days = res.predict(start = len(df), end = len(df) + 90 - 1)

# Print the predicted closing prices for the next 30 days
print('Predicted closing prices for the next 90 days:')
print(y_next_90_days)
# Out:
# Predicted closing prices for the next 90 days:
# 2344    804.302738
# 2345    804.730791
# 2346    803.609432
# 2347    806.786076
# 2348    800.591463
#            ...
# 2429    682.746124
# 2430    678.163958
# 2431    677.525017
# 2432    678.822829
# 2433    674.000902
# Length: 90, dtype: float64

# %%
dt_train = np.append(train_df, predicted.iloc[0])

# %%
fig, ax = plt.subplots()

plt.plot(pd.RangeIndex(start=0, stop=len(dt_train), step=1), dt_train)
plt.plot(test_df.index, test_df)
plt.plot(test_df.index, predicted)
plt.plot(last_data,y_next_90_days)
plt.plot(pd.RangeIndex(start=last_index, stop=last_index+60, step=1),y_next_90_days[0:60])
plt.plot(pd.RangeIndex(start=last_index, stop=last_index+30, step=1),y_next_90_days[0:30])
plt.legend(['Train', 'Test', 'Predictions', 'Next 90 days Predictions', 'Next 60 days Predictions', 'Next 30 days Predictions'])
plt.show()
