# %%
from statsmodels.tsa.exponential_smoothing.ets import ETSModel
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.metrics import mean_squared_error
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from sklearn.metrics import r2_score as r2_score
from sklearn.metrics import mean_squared_error as mse

from itertools import product

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = [18, 10]

# %% [markdown]
# ## Importing Dataset

# %%
df = pd.read_csv("../../Dataset/Platinum.csv")
df
# Out:
#             Date    Open   Close    High     Low
# 0     2018-01-01   933.5   930.5   933.5   930.5
# 1     2018-01-02   931.0   945.5   946.5   931.0
# 2     2018-01-03   945.0   957.0   961.0   940.5
# 3     2018-01-04   955.0   964.0   966.5   945.0
# 4     2018-01-05   963.0   969.5   970.5   959.5
# ...          ...     ...     ...     ...     ...
# 2339  2024-05-28  1056.0  1059.5  1068.0  1045.0
# 2340  2024-05-29  1061.5  1040.5  1064.0  1036.0
# 2341  2024-05-30  1040.0  1031.5  1043.0  1022.5
# 2342  2024-05-31  1028.0  1038.5  1051.5  1020.0
# 2343  2024-06-01  1038.5  1038.5  1038.5  1038.5
#
# [2344 rows x 5 columns]

# %%
df.dtypes
# Out:
# Date      object
# Open     float64
# Close    float64
# High     float64
# Low      float64
# dtype: object

# %%
df = df[["Close"]]
df.reset_index(drop=True)
# Out:
#        Close
# 0      930.5
# 1      945.5
# 2      957.0
# 3      964.0
# 4      969.5
# ...      ...
# 2339  1059.5
# 2340  1040.5
# 2341  1031.5
# 2342  1038.5
# 2343  1038.5
#
# [2344 rows x 1 columns]

# %%
df.head()
# Out:
#    Close
# 0  930.5
# 1  945.5
# 2  957.0
# 3  964.0
# 4  969.5

# %%
#Đồ thị giá đóng
df.Close.plot(figsize = (10, 7))
plt.ylabel("Platinum price")
plt.show()

# %%
#train test split
train_size = int(0.6 * len(df))

train_df = df[:train_size]
test_df = df[train_size:]

# %%
model = ETSModel(
    train_df['Close'],
    error="mul",
    trend="add",
    seasonal="mul",
    damped_trend=False,
    seasonal_periods=90)

res = model.fit()
print(res.summary())
# Out:
#                                  ETS Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 1406
# Model:                       ETS(MAM)   Log Likelihood               -5583.946
# Date:                Thu, 13 Jun 2024   AIC                          11359.893
# Time:                        11:21:40   BIC                          11863.749
# Sample:                             0   HQIC                         11548.205
#                                - 1406   Scale                            0.000
# Covariance Type:               approx
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# smoothing_level         0.9999      0.021     47.064      0.000       0.958       1.042
# smoothing_trend      9.999e-05        nan        nan        nan         nan         nan
# smoothing_seasonal   3.496e-05        nan        nan        nan         nan         nan
# initial_level         978.7630        nan        nan        nan         nan         nan
# initial_trend           0.1021      0.339      0.301      0.763      -0.562       0.766
# initial_seasonal.0      1.0030        nan        nan        nan         nan         nan
# initial_seasonal.1      0.9999        nan        nan        nan         nan         nan
# initial_seasonal.2      1.0054        nan        nan        nan         nan         nan
# initial_seasonal.3      1.0105        nan        nan        nan         nan         nan
# initial_seasonal.4      1.0085        nan        nan        nan         nan         nan
# initial_seasonal.5      1.0232        nan        nan        nan         nan         nan
# initial_seasonal.6      1.0211        nan        nan        nan         nan         nan
# initial_seasonal.7      1.0186        nan        nan        nan         nan         nan
# initial_seasonal.8      1.0182        nan        nan        nan         nan         nan
# initial_seasonal.9      1.0263        nan        nan        nan         nan         nan
# initial_seasonal.10     1.0262        nan        nan        nan         nan         nan
# initial_seasonal.11     1.0259        nan        nan        nan         nan         nan
# initial_seasonal.12     1.0266        nan        nan        nan         nan         nan
# initial_seasonal.13     1.0305        nan        nan        nan         nan         nan
# initial_seasonal.14     1.0311        nan        nan        nan         nan         nan
# initial_seasonal.15     1.0267        nan        nan        nan         nan         nan
# initial_seasonal.16     1.0251        nan        nan        nan         nan         nan
# initial_seasonal.17     1.0287        nan        nan        nan         nan         nan
# initial_seasonal.18     1.0339        nan        nan        nan         nan         nan
# initial_seasonal.19     1.0343        nan        nan        nan         nan         nan
# initial_seasonal.20     1.0301        nan        nan        nan         nan         nan
# initial_seasonal.21     1.0350        nan        nan        nan         nan         nan
# initial_seasonal.22     1.0328        nan        nan        nan         nan         nan
# initial_seasonal.23     1.0343        nan        nan        nan         nan         nan
# initial_seasonal.24     1.0374        nan        nan        nan         nan         nan
# initial_seasonal.25     1.0408        nan        nan        nan         nan         nan
# initial_seasonal.26     1.0413        nan        nan        nan         nan         nan
# initial_seasonal.27     1.0443        nan        nan        nan         nan         nan
# initial_seasonal.28     1.0465        nan        nan        nan         nan         nan
# initial_seasonal.29     1.0476        nan        nan        nan         nan         nan
# initial_seasonal.30     1.0464        nan        nan        nan         nan         nan
# initial_seasonal.31     1.0443        nan        nan        nan         nan         nan
# initial_seasonal.32     1.0372        nan        nan        nan         nan         nan
# initial_seasonal.33     1.0346        nan        nan        nan         nan         nan
# initial_seasonal.34     1.0332        nan        nan        nan         nan         nan
# initial_seasonal.35     1.0271        nan        nan        nan         nan         nan
# initial_seasonal.36     1.0249        nan        nan        nan         nan         nan
# initial_seasonal.37     1.0315        nan        nan        nan         nan         nan
# initial_seasonal.38     1.0303        nan        nan        nan         nan         nan
# initial_seasonal.39     1.0316        nan        nan        nan         nan         nan
# initial_seasonal.40     1.0308        nan        nan        nan         nan         nan
# initial_seasonal.41     1.0316        nan        nan        nan         nan         nan
# initial_seasonal.42     1.0288        nan        nan        nan         nan         nan
# initial_seasonal.43     1.0216        nan        nan        nan         nan         nan
# initial_seasonal.44     1.0273        nan        nan        nan         nan         nan
# initial_seasonal.45     1.0302        nan        nan        nan         nan         nan
# initial_seasonal.46     1.0319        nan        nan        nan         nan         nan
# initial_seasonal.47     1.0335        nan        nan        nan         nan         nan
# initial_seasonal.48     1.0410        nan        nan        nan         nan         nan
# initial_seasonal.49     1.0443        nan        nan        nan         nan         nan
# initial_seasonal.50     1.0481        nan        nan        nan         nan         nan
# initial_seasonal.51     1.0501        nan        nan        nan         nan         nan
# initial_seasonal.52     1.0455        nan        nan        nan         nan         nan
# initial_seasonal.53     1.0472        nan        nan        nan         nan         nan
# initial_seasonal.54     1.0482        nan        nan        nan         nan         nan
# initial_seasonal.55     1.0513        nan        nan        nan         nan         nan
# initial_seasonal.56     1.0470        nan        nan        nan         nan         nan
# initial_seasonal.57     1.0409        nan        nan        nan         nan         nan
# initial_seasonal.58     1.0403        nan        nan        nan         nan         nan
# initial_seasonal.59     1.0377        nan        nan        nan         nan         nan
# initial_seasonal.60     1.0380        nan        nan        nan         nan         nan
# initial_seasonal.61     1.0362        nan        nan        nan         nan         nan
# initial_seasonal.62     1.0319        nan        nan        nan         nan         nan
# initial_seasonal.63     1.0341        nan        nan        nan         nan         nan
# initial_seasonal.64     1.0330        nan        nan        nan         nan         nan
# initial_seasonal.65     1.0322        nan        nan        nan         nan         nan
# initial_seasonal.66     1.0305        nan        nan        nan         nan         nan
# initial_seasonal.67     1.0308        nan        nan        nan         nan         nan
# initial_seasonal.68     1.0303        nan        nan        nan         nan         nan
# initial_seasonal.69     1.0302        nan        nan        nan         nan         nan
# initial_seasonal.70     1.0243        nan        nan        nan         nan         nan
# initial_seasonal.71     1.0265        nan        nan        nan         nan         nan
# initial_seasonal.72     1.0233        nan        nan        nan         nan         nan
# initial_seasonal.73     1.0228        nan        nan        nan         nan         nan
# initial_seasonal.74     1.0204        nan        nan        nan         nan         nan
# initial_seasonal.75     1.0219        nan        nan        nan         nan         nan
# initial_seasonal.76     1.0230        nan        nan        nan         nan         nan
# initial_seasonal.77     1.0231        nan        nan        nan         nan         nan
# initial_seasonal.78     1.0198        nan        nan        nan         nan         nan
# initial_seasonal.79     1.0163        nan        nan        nan         nan         nan
# initial_seasonal.80     1.0119        nan        nan        nan         nan         nan
# initial_seasonal.81     1.0095        nan        nan        nan         nan         nan
# initial_seasonal.82     1.0038        nan        nan        nan         nan         nan
# initial_seasonal.83     1.0035        nan        nan        nan         nan         nan
# initial_seasonal.84     1.0042        nan        nan        nan         nan         nan
# initial_seasonal.85     1.0094        nan        nan        nan         nan         nan
# initial_seasonal.86     1.0109        nan        nan        nan         nan         nan
# initial_seasonal.87     1.0012        nan        nan        nan         nan         nan
# initial_seasonal.88     1.0021        nan        nan        nan         nan         nan
# initial_seasonal.89     1.0000        nan        nan        nan         nan         nan
# ===================================================================================
# Ljung-Box (Q):                      332.03   Jarque-Bera (JB):              3756.88
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.88   Skew:                            -0.29
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.99
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.

# %% [markdown]
# ## FORECASTING

# %%
predicted = res.predict(start = len(train_df), end = len(train_df) + len(test_df) - 1)

# %%
mape = np.mean(np.abs(predicted - test_df['Close'])/np.abs(test_df['Close'])) *100
mse = np.mean(np.square(test_df['Close'] - predicted))
rmse = np.sqrt(mse)

print("Mean Absolute Percentage Error (MAPE):", mape)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Mean Absolute Percentage Error (MAPE): 12.66589444224242
# Mean Squared Error (MSE): 18391.562420535094
# Root Mean Squared Error (RMSE): 135.61549476566125

# %%
# Quá trình tạo index predict 90 ngày tiếp theo
last_index =  df.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+90, step=1)

# Predict the closing prices for the next 90 days
y_next_90_days = res.predict(start = len(df), end = len(df) + 90 - 1)

# Print the predicted closing prices for the next 30 days
print('Predicted closing prices for the next 90 days:')
print(y_next_90_days)
# Out:
# Predicted closing prices for the next 90 days:
# 2344    1100.505114
# 2345    1094.904018
# 2346    1094.180897
# 2347    1094.674781
# 2348    1100.992412
#            ...
# 2429    1101.324263
# 2430    1098.158394
# 2431    1100.516466
# 2432    1099.669471
# 2433    1110.366391
# Length: 90, dtype: float64

# %%
predicted
# Out:
# 1406    1038.543415
# 1407    1041.209484
# 1408    1048.454435
# 1409    1050.605007
# 1410    1051.890759
#            ...
# 2339    1093.003266
# 2340    1089.862014
# 2341    1092.202969
# 2342    1091.363068
# 2343    1101.979893
# Length: 938, dtype: float64

# %%
dt_train = np.append(train_df, predicted.iloc[0])

# %%
fig, ax = plt.subplots()

plt.plot(pd.RangeIndex(start=0, stop=len(dt_train), step=1), dt_train)
plt.plot(test_df.index, test_df)
plt.plot(test_df.index, predicted)
plt.plot(last_data,y_next_90_days)
plt.plot(pd.RangeIndex(start=last_index, stop=last_index+60, step=1),y_next_90_days[0:60])
plt.plot(pd.RangeIndex(start=last_index, stop=last_index+30, step=1),y_next_90_days[0:30])
plt.legend(['Train', 'Test', 'Predictions', 'Next 90 days Predictions', 'Next 60 days Predictions', 'Next 30 days Predictions'])
plt.show()
