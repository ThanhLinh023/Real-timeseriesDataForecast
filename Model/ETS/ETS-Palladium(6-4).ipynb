# %%
from statsmodels.tsa.exponential_smoothing.ets import ETSModel
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.metrics import mean_squared_error
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from sklearn.metrics import r2_score as r2_score
from sklearn.metrics import mean_squared_error as mse

from itertools import product

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = [18, 10]

# %% [markdown]
# ## Importing Dataset

# %%
df = pd.read_csv("../../Dataset/Palladium.csv")
df
# Out:
#             Date    Open   Close    High     Low
# 0     2018-01-01  1067.5  1067.5  1067.5  1067.5
# 1     2018-01-02  1066.5  1096.0  1099.0  1066.0
# 2     2018-01-03  1095.5  1088.0  1097.0  1084.0
# 3     2018-01-04  1086.5  1102.5  1108.5  1083.5
# 4     2018-01-05  1100.0  1091.5  1103.0  1086.5
# ...          ...     ...     ...     ...     ...
# 2339  2024-05-28   995.5   975.5   997.0   969.5
# 2340  2024-05-29   982.5   968.0   983.0   946.5
# 2341  2024-05-30   957.0   950.5   962.0   932.5
# 2342  2024-05-31   949.5   914.5   956.0   903.5
# 2343  2024-06-01   914.5   914.5   914.5   914.5
#
# [2344 rows x 5 columns]

# %%
df.dtypes
# Out:
# Date      object
# Open     float64
# Close    float64
# High     float64
# Low      float64
# dtype: object

# %%
df = df[["Close"]]
df.reset_index(drop=True)
# Out:
#        Close
# 0     1067.5
# 1     1096.0
# 2     1088.0
# 3     1102.5
# 4     1091.5
# ...      ...
# 2339   975.5
# 2340   968.0
# 2341   950.5
# 2342   914.5
# 2343   914.5
#
# [2344 rows x 1 columns]

# %%
df.head()
# Out:
#     Close
# 0  1067.5
# 1  1096.0
# 2  1088.0
# 3  1102.5
# 4  1091.5

# %%
#Đồ thị giá đóng
df.Close.plot(figsize = (10, 7))
plt.ylabel("Palladium price")
plt.show()

# %%
#train test split
train_size = int(0.6 * len(df))

train_df = df[:train_size]
test_df = df[train_size:]

# %%
model = ETSModel(
    train_df['Close'],
    error="mul",
    trend="add",
    seasonal="mul",
    damped_trend=False,
    seasonal_periods=90)

res = model.fit()
print(res.summary())
# Out:
#                                  ETS Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 1406
# Model:                       ETS(MAM)   Log Likelihood               -6779.928
# Date:                Thu, 13 Jun 2024   AIC                          13751.855
# Time:                        11:20:27   BIC                          14255.712
# Sample:                             0   HQIC                         13940.168
#                                - 1406   Scale                            0.000
# Covariance Type:               approx
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# smoothing_level         0.9999      0.021     46.620      0.000       0.958       1.042
# smoothing_trend         0.0038      0.005      0.754      0.451      -0.006       0.014
# smoothing_seasonal   5.673e-06        nan        nan        nan         nan         nan
# initial_level        1037.7197     79.717     13.018      0.000     881.478    1193.962
# initial_trend          -1.8377      3.973     -0.463      0.644      -9.624       5.949
# initial_seasonal.0      1.0035      0.077     13.065      0.000       0.853       1.154
# initial_seasonal.1      1.0034      0.077     13.046      0.000       0.853       1.154
# initial_seasonal.2      1.0020      0.077     13.027      0.000       0.851       1.153
# initial_seasonal.3      1.0069      0.077     13.012      0.000       0.855       1.159
# initial_seasonal.4      1.0068      0.077     12.992      0.000       0.855       1.159
# initial_seasonal.5      1.0189      0.079     12.972      0.000       0.865       1.173
# initial_seasonal.6      1.0182      0.079     12.955      0.000       0.864       1.172
# initial_seasonal.7      1.0208      0.079     12.939      0.000       0.866       1.175
# initial_seasonal.8      1.0234      0.079     12.920      0.000       0.868       1.179
# initial_seasonal.9      1.0355      0.080     12.905      0.000       0.878       1.193
# initial_seasonal.10     1.0399      0.081     12.889      0.000       0.882       1.198
# initial_seasonal.11     1.0394      0.081     12.871      0.000       0.881       1.198
# initial_seasonal.12     1.0372      0.081     12.855      0.000       0.879       1.195
# initial_seasonal.13     1.0388      0.081     12.839      0.000       0.880       1.197
# initial_seasonal.14     1.0371      0.081     12.825      0.000       0.879       1.196
# initial_seasonal.15     1.0352      0.081     12.813      0.000       0.877       1.194
# initial_seasonal.16     1.0329      0.081     12.800      0.000       0.875       1.191
# initial_seasonal.17     1.0349      0.081     12.787      0.000       0.876       1.194
# initial_seasonal.18     1.0380      0.081     12.775      0.000       0.879       1.197
# initial_seasonal.19     1.0360      0.081     12.759      0.000       0.877       1.195
# initial_seasonal.20     1.0279      0.081     12.747      0.000       0.870       1.186
# initial_seasonal.21     1.0311      0.081     12.737      0.000       0.872       1.190
# initial_seasonal.22     1.0384      0.082     12.725      0.000       0.878       1.198
# initial_seasonal.23     1.0365      0.081     12.719      0.000       0.877       1.196
# initial_seasonal.24     1.0353      0.081     12.706      0.000       0.876       1.195
# initial_seasonal.25     1.0366      0.082     12.695      0.000       0.877       1.197
# initial_seasonal.26     1.0428      0.082     12.688      0.000       0.882       1.204
# initial_seasonal.27     1.0446      0.082     12.677      0.000       0.883       1.206
# initial_seasonal.28     1.0461      0.083     12.672      0.000       0.884       1.208
# initial_seasonal.29     1.0455      0.083     12.667      0.000       0.884       1.207
# initial_seasonal.30     1.0396      0.082     12.657      0.000       0.879       1.201
# initial_seasonal.31     1.0374      0.082     12.653      0.000       0.877       1.198
# initial_seasonal.32     1.0275      0.081     12.650      0.000       0.868       1.187
# initial_seasonal.33     1.0271      0.081     12.647      0.000       0.868       1.186
# initial_seasonal.34     1.0300      0.081     12.644      0.000       0.870       1.190
# initial_seasonal.35     1.0280      0.081     12.638      0.000       0.869       1.187
# initial_seasonal.36     1.0243      0.081     12.633      0.000       0.865       1.183
# initial_seasonal.37     1.0310      0.082     12.628      0.000       0.871       1.191
# initial_seasonal.38     1.0286      0.081     12.622      0.000       0.869       1.188
# initial_seasonal.39     1.0298      0.082     12.616      0.000       0.870       1.190
# initial_seasonal.40     1.0242      0.081     12.612      0.000       0.865       1.183
# initial_seasonal.41     1.0221      0.081     12.611      0.000       0.863       1.181
# initial_seasonal.42     1.0172      0.081     12.609      0.000       0.859       1.175
# initial_seasonal.43     1.0081      0.080     12.605      0.000       0.851       1.165
# initial_seasonal.44     1.0127      0.080     12.604      0.000       0.855       1.170
# initial_seasonal.45     1.0156      0.081     12.606      0.000       0.858       1.173
# initial_seasonal.46     1.0152      0.081     12.607      0.000       0.857       1.173
# initial_seasonal.47     1.0155      0.081     12.607      0.000       0.858       1.173
# initial_seasonal.48     1.0182      0.081     12.610      0.000       0.860       1.177
# initial_seasonal.49     1.0249      0.081     12.613      0.000       0.866       1.184
# initial_seasonal.50     1.0291      0.082     12.618      0.000       0.869       1.189
# initial_seasonal.51     1.0307      0.082     12.617      0.000       0.871       1.191
# initial_seasonal.52     1.0288      0.082     12.619      0.000       0.869       1.189
# initial_seasonal.53     1.0338      0.082     12.623      0.000       0.873       1.194
# initial_seasonal.54     1.0373      0.082     12.629      0.000       0.876       1.198
# initial_seasonal.55     1.0408      0.082     12.635      0.000       0.879       1.202
# initial_seasonal.56     1.0371      0.082     12.642      0.000       0.876       1.198
# initial_seasonal.57     1.0401      0.082     12.648      0.000       0.879       1.201
# initial_seasonal.58     1.0419      0.082     12.655      0.000       0.881       1.203
# initial_seasonal.59     1.0430      0.082     12.664      0.000       0.882       1.204
# initial_seasonal.60     1.0478      0.083     12.674      0.000       0.886       1.210
# initial_seasonal.61     1.0476      0.083     12.685      0.000       0.886       1.210
# initial_seasonal.62     1.0461      0.082     12.694      0.000       0.885       1.208
# initial_seasonal.63     1.0446      0.082     12.704      0.000       0.883       1.206
# initial_seasonal.64     1.0427      0.082     12.712      0.000       0.882       1.203
# initial_seasonal.65     1.0405      0.082     12.723      0.000       0.880       1.201
# initial_seasonal.66     1.0384      0.082     12.734      0.000       0.879       1.198
# initial_seasonal.67     1.0332      0.081     12.742      0.000       0.874       1.192
# initial_seasonal.68     1.0367      0.081     12.754      0.000       0.877       1.196
# initial_seasonal.69     1.0326      0.081     12.765      0.000       0.874       1.191
# initial_seasonal.70     1.0260      0.080     12.775      0.000       0.869       1.183
# initial_seasonal.71     1.0324      0.081     12.785      0.000       0.874       1.191
# initial_seasonal.72     1.0304      0.081     12.796      0.000       0.873       1.188
# initial_seasonal.73     1.0283      0.080     12.811      0.000       0.871       1.186
# initial_seasonal.74     1.0282      0.080     12.823      0.000       0.871       1.185
# initial_seasonal.75     1.0249      0.080     12.838      0.000       0.868       1.181
# initial_seasonal.76     1.0229      0.080     12.854      0.000       0.867       1.179
# initial_seasonal.77     1.0287      0.080     12.872      0.000       0.872       1.185
# initial_seasonal.78     1.0245      0.080     12.886      0.000       0.869       1.180
# initial_seasonal.79     1.0246      0.079     12.896      0.000       0.869       1.180
# initial_seasonal.80     1.0189      0.079     12.910      0.000       0.864       1.174
# initial_seasonal.81     1.0126      0.078     12.931      0.000       0.859       1.166
# initial_seasonal.82     1.0167      0.079     12.948      0.000       0.863       1.171
# initial_seasonal.83     1.0122      0.078     12.963      0.000       0.859       1.165
# initial_seasonal.84     1.0133      0.078     12.984      0.000       0.860       1.166
# initial_seasonal.85     1.0173      0.078     12.998      0.000       0.864       1.171
# initial_seasonal.86     1.0065      0.077     13.020      0.000       0.855       1.158
# initial_seasonal.87     1.0043      0.077     13.041      0.000       0.853       1.155
# initial_seasonal.88     0.9990      0.076     13.063      0.000       0.849       1.149
# initial_seasonal.89     1.0000      0.076     13.086      0.000       0.850       1.150
# ===================================================================================
# Ljung-Box (Q):                      257.26   Jarque-Bera (JB):             22367.45
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.69   Skew:                            -0.27
# Prob(H) (two-sided):                  0.00   Kurtosis:                        22.53
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.

# %% [markdown]
# ## FORECASTING

# %%
predicted = res.predict(start = len(train_df), end = len(train_df) + len(test_df) - 1)

# %%
mape = np.mean(np.abs(predicted - test_df['Close'])/np.abs(test_df['Close'])) *100
mse = np.mean(np.square(test_df['Close'] - predicted))
rmse = np.sqrt(mse)

print("Mean Absolute Percentage Error (MAPE):", mape)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Mean Absolute Percentage Error (MAPE): 11.45828066383586
# Mean Squared Error (MSE): 70750.30648589924
# Root Mean Squared Error (RMSE): 265.989297690526

# %%
# Quá trình tạo index predict 90 ngày tiếp theo
last_index =  df.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+90, step=1)

# Predict the closing prices for the next 90 days
y_next_90_days = res.predict(start = len(df), end = len(df) + 90 - 1)

# Print the predicted closing prices for the next 30 days
print('Predicted closing prices for the next 90 days:')
print(y_next_90_days)
# Out:
# Predicted closing prices for the next 90 days:
# 2344    1013.243224
# 2345    1008.122472
# 2346    1006.045724
# 2347    1009.460180
# 2348    1004.332341
#            ...
# 2429     910.239921
# 2430     905.974046
# 2431     904.033215
# 2432     907.776820
# 2433     908.665636
# Length: 90, dtype: float64

# %%
dt_train = np.append(train_df, predicted.iloc[0])

# %%
fig, ax = plt.subplots()

plt.plot(pd.RangeIndex(start=0, stop=len(dt_train), step=1), dt_train)
plt.plot(test_df.index, test_df)
plt.plot(test_df.index, predicted)
plt.plot(last_data,y_next_90_days)
plt.plot(pd.RangeIndex(start=last_index, stop=last_index+60, step=1),y_next_90_days[0:60])
plt.plot(pd.RangeIndex(start=last_index, stop=last_index+30, step=1),y_next_90_days[0:30])
plt.legend(['Train', 'Test', 'Predictions', 'Next 90 days Predictions', 'Next 60 days Predictions', 'Next 30 days Predictions'])
plt.show()
