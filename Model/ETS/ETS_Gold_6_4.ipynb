# %%
from statsmodels.tsa.exponential_smoothing.ets import ETSModel
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.metrics import mean_squared_error
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from sklearn.metrics import r2_score as r2_score
from sklearn.metrics import mean_squared_error as mse

from itertools import product

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = [18, 10]

# %% [markdown]
# ## Importing Dataset

# %%
df = pd.read_csv("../../Dataset/Gold.csv")
df
# Out:
#             Date      Open     Close        High        Low
# 0     2018-01-01  1300.760  1313.075  1316.08375  1300.6425
# 1     2018-01-02  1302.910  1316.500  1318.91000  1302.8550
# 2     2018-01-03  1318.375  1318.875  1321.30000  1307.7100
# 3     2018-01-04  1313.105  1327.875  1327.87500  1306.0500
# 4     2018-01-05  1322.050  1319.590  1323.50500  1313.9100
# ...          ...       ...       ...         ...        ...
# 2339  2024-05-28  2352.200  2361.310  2363.46000  2340.4200
# 2340  2024-05-29  2361.390  2339.110  2361.79000  2335.0700
# 2341  2024-05-30  2338.880  2343.380  2351.09000  2323.0300
# 2342  2024-05-31  2343.340  2327.820  2359.58000  2320.6300
# 2343  2024-06-01  2327.820  2327.820  2327.82000  2327.8200
#
# [2344 rows x 5 columns]

# %%
df.dtypes
# Out:
# Date      object
# Open     float64
# Close    float64
# High     float64
# Low      float64
# dtype: object

# %%
df = df[["Close"]]
df.reset_index(drop=True)
# Out:
#          Close
# 0     1313.075
# 1     1316.500
# 2     1318.875
# 3     1327.875
# 4     1319.590
# ...        ...
# 2339  2361.310
# 2340  2339.110
# 2341  2343.380
# 2342  2327.820
# 2343  2327.820
#
# [2344 rows x 1 columns]

# %%
df.head()
# Out:
#       Close
# 0  1313.075
# 1  1316.500
# 2  1318.875
# 3  1327.875
# 4  1319.590

# %%
#Đồ thị giá đóng
df.Close.plot(figsize = (10, 7))
plt.ylabel("Gold price")
plt.show()

# %%
#train test split
train_size = int(0.6 * len(df))

train_df = df[:train_size]
test_df = df[train_size:]

# %%
model = ETSModel(
    train_df['Close'],
    error="mul",
    trend="add",
    seasonal="mul",
    damped_trend=False,
    seasonal_periods=90)

res = model.fit()
print(res.summary())
# Out:
#                                  ETS Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 1406
# Model:                       ETS(MAM)   Log Likelihood               -5423.317
# Date:                Thu, 13 Jun 2024   AIC                          11038.633
# Time:                        11:19:53   BIC                          11542.490
# Sample:                             0   HQIC                         11226.946
#                                - 1406   Scale                            0.000
# Covariance Type:               approx
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# smoothing_level         0.9999      0.025     40.175      0.000       0.951       1.049
# smoothing_trend      9.999e-05        nan        nan        nan         nan         nan
# smoothing_seasonal       1e-08        nan        nan        nan         nan         nan
# initial_level        1329.9680        nan        nan        nan         nan         nan
# initial_trend           0.1870      0.131      1.431      0.152      -0.069       0.443
# initial_seasonal.0      0.9989        nan        nan        nan         nan         nan
# initial_seasonal.1      0.9966        nan        nan        nan         nan         nan
# initial_seasonal.2      0.9980        nan        nan        nan         nan         nan
# initial_seasonal.3      0.9992        nan        nan        nan         nan         nan
# initial_seasonal.4      0.9988        nan        nan        nan         nan         nan
# initial_seasonal.5      1.0003        nan        nan        nan         nan         nan
# initial_seasonal.6      1.0004        nan        nan        nan         nan         nan
# initial_seasonal.7      0.9986        nan        nan        nan         nan         nan
# initial_seasonal.8      1.0006        nan        nan        nan         nan         nan
# initial_seasonal.9      0.9996        nan        nan        nan         nan         nan
# initial_seasonal.10     1.0003        nan        nan        nan         nan         nan
# initial_seasonal.11     0.9998        nan        nan        nan         nan         nan
# initial_seasonal.12     1.0002        nan        nan        nan         nan         nan
# initial_seasonal.13     1.0018        nan        nan        nan         nan         nan
# initial_seasonal.14     1.0026        nan        nan        nan         nan         nan
# initial_seasonal.15     1.0036        nan        nan        nan         nan         nan
# initial_seasonal.16     1.0035        nan        nan        nan         nan         nan
# initial_seasonal.17     1.0050        nan        nan        nan         nan         nan
# initial_seasonal.18     1.0062        nan        nan        nan         nan         nan
# initial_seasonal.19     1.0067        nan        nan        nan         nan         nan
# initial_seasonal.20     1.0031        nan        nan        nan         nan         nan
# initial_seasonal.21     1.0036        nan        nan        nan         nan         nan
# initial_seasonal.22     1.0039        nan        nan        nan         nan         nan
# initial_seasonal.23     1.0040        nan        nan        nan         nan         nan
# initial_seasonal.24     1.0060        nan        nan        nan         nan         nan
# initial_seasonal.25     1.0071        nan        nan        nan         nan         nan
# initial_seasonal.26     1.0060        nan        nan        nan         nan         nan
# initial_seasonal.27     1.0072        nan        nan        nan         nan         nan
# initial_seasonal.28     1.0078        nan        nan        nan         nan         nan
# initial_seasonal.29     1.0110        nan        nan        nan         nan         nan
# initial_seasonal.30     1.0089        nan        nan        nan         nan         nan
# initial_seasonal.31     1.0058        nan        nan        nan         nan         nan
# initial_seasonal.32     1.0041        nan        nan        nan         nan         nan
# initial_seasonal.33     1.0057        nan        nan        nan         nan         nan
# initial_seasonal.34     1.0069        nan        nan        nan         nan         nan
# initial_seasonal.35     1.0058        nan        nan        nan         nan         nan
# initial_seasonal.36     1.0026        nan        nan        nan         nan         nan
# initial_seasonal.37     1.0086        nan        nan        nan         nan         nan
# initial_seasonal.38     1.0084        nan        nan        nan         nan         nan
# initial_seasonal.39     1.0073        nan        nan        nan         nan         nan
# initial_seasonal.40     1.0087        nan        nan        nan         nan         nan
# initial_seasonal.41     1.0072        nan        nan        nan         nan         nan
# initial_seasonal.42     1.0077        nan        nan        nan         nan         nan
# initial_seasonal.43     1.0069        nan        nan        nan         nan         nan
# initial_seasonal.44     1.0062        nan        nan        nan         nan         nan
# initial_seasonal.45     1.0059        nan        nan        nan         nan         nan
# initial_seasonal.46     1.0083        nan        nan        nan         nan         nan
# initial_seasonal.47     1.0078        nan        nan        nan         nan         nan
# initial_seasonal.48     1.0086        nan        nan        nan         nan         nan
# initial_seasonal.49     1.0093        nan        nan        nan         nan         nan
# initial_seasonal.50     1.0088        nan        nan        nan         nan         nan
# initial_seasonal.51     1.0081        nan        nan        nan         nan         nan
# initial_seasonal.52     1.0067        nan        nan        nan         nan         nan
# initial_seasonal.53     1.0074        nan        nan        nan         nan         nan
# initial_seasonal.54     1.0093        nan        nan        nan         nan         nan
# initial_seasonal.55     1.0092        nan        nan        nan         nan         nan
# initial_seasonal.56     1.0060        nan        nan        nan         nan         nan
# initial_seasonal.57     1.0056        nan        nan        nan         nan         nan
# initial_seasonal.58     1.0057        nan        nan        nan         nan         nan
# initial_seasonal.59     1.0030        nan        nan        nan         nan         nan
# initial_seasonal.60     1.0022        nan        nan        nan         nan         nan
# initial_seasonal.61     1.0012        nan        nan        nan         nan         nan
# initial_seasonal.62     1.0017        nan        nan        nan         nan         nan
# initial_seasonal.63     1.0039        nan        nan        nan         nan         nan
# initial_seasonal.64     1.0050        nan        nan        nan         nan         nan
# initial_seasonal.65     1.0055        nan        nan        nan         nan         nan
# initial_seasonal.66     1.0070        nan        nan        nan         nan         nan
# initial_seasonal.67     1.0067        nan        nan        nan         nan         nan
# initial_seasonal.68     1.0061        nan        nan        nan         nan         nan
# initial_seasonal.69     1.0063        nan        nan        nan         nan         nan
# initial_seasonal.70     1.0057        nan        nan        nan         nan         nan
# initial_seasonal.71     1.0044        nan        nan        nan         nan         nan
# initial_seasonal.72     1.0027        nan        nan        nan         nan         nan
# initial_seasonal.73     1.0050        nan        nan        nan         nan         nan
# initial_seasonal.74     1.0028        nan        nan        nan         nan         nan
# initial_seasonal.75     1.0020        nan        nan        nan         nan         nan
# initial_seasonal.76     1.0022        nan        nan        nan         nan         nan
# initial_seasonal.77     1.0007        nan        nan        nan         nan         nan
# initial_seasonal.78     0.9995        nan        nan        nan         nan         nan
# initial_seasonal.79     0.9991        nan        nan        nan         nan         nan
# initial_seasonal.80     1.0014        nan        nan        nan         nan         nan
# initial_seasonal.81     0.9988        nan        nan        nan         nan         nan
# initial_seasonal.82     0.9997        nan        nan        nan         nan         nan
# initial_seasonal.83     0.9979        nan        nan        nan         nan         nan
# initial_seasonal.84     1.0005        nan        nan        nan         nan         nan
# initial_seasonal.85     1.0006        nan        nan        nan         nan         nan
# initial_seasonal.86     1.0040        nan        nan        nan         nan         nan
# initial_seasonal.87     1.0019        nan        nan        nan         nan         nan
# initial_seasonal.88     1.0013        nan        nan        nan         nan         nan
# initial_seasonal.89     1.0000        nan        nan        nan         nan         nan
# ===================================================================================
# Ljung-Box (Q):                      263.08   Jarque-Bera (JB):              2681.10
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.43   Skew:                            -0.35
# Prob(H) (two-sided):                  0.00   Kurtosis:                         9.73
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.

# %% [markdown]
# ## FORECASTING

# %%
predicted = res.predict(start = len(train_df), end = len(train_df) + len(test_df) - 1)

# %%
mape = np.mean(np.abs(predicted - test_df['Close'])/np.abs(test_df['Close'])) *100
mse = np.mean(np.square(test_df['Close'] - predicted))
rmse = np.sqrt(mse)

print("Mean Absolute Percentage Error (MAPE):", mape)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Mean Absolute Percentage Error (MAPE): 4.599199863076071
# Mean Squared Error (MSE): 16220.785810350379
# Root Mean Squared Error (RMSE): 127.36084881293144

# %%
# Quá trình tạo index predict 90 ngày tiếp theo
last_index =  df.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+90, step=1)

# Predict the closing prices for the next 90 days
y_next_90_days = res.predict(start = len(df), end = len(df) + 90 - 1)

# Print the predicted closing prices for the next 30 days
print('Predicted closing prices for the next 90 days:')
print(y_next_90_days)
# Out:
# Predicted closing prices for the next 90 days:
# 2344    2000.889315
# 2345    2001.006239
# 2346    1995.822709
# 2347    1999.763454
# 2348    1998.212138
#            ...
# 2429    2015.162040
# 2430    2017.507671
# 2431    2020.371561
# 2432    2021.802805
# 2433    2026.274540
# Length: 90, dtype: float64

# %%
dt_train = np.append(train_df, predicted.iloc[0])

# %%
fig, ax = plt.subplots()

plt.plot(pd.RangeIndex(start=0, stop=len(dt_train), step=1), dt_train)
plt.plot(test_df.index, test_df)
plt.plot(test_df.index, predicted)
plt.plot(last_data,y_next_90_days)
plt.plot(pd.RangeIndex(start=last_index, stop=last_index+60, step=1),y_next_90_days[0:60])
plt.plot(pd.RangeIndex(start=last_index, stop=last_index+30, step=1),y_next_90_days[0:30])
plt.legend(['Train', 'Test', 'Predictions', 'Next 90 days Predictions', 'Next 60 days Predictions', 'Next 30 days Predictions'])
plt.show()
