# %%
from statsmodels.tsa.exponential_smoothing.ets import ETSModel
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.metrics import mean_squared_error
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from sklearn.metrics import r2_score as r2_score
from sklearn.metrics import mean_squared_error as mse

from itertools import product

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = [18, 10]

# %% [markdown]
# ## Importing Dataset

# %%
df = pd.read_csv("../../Dataset/Palladium.csv")
df
# Out:
#             Date    Open   Close    High     Low
# 0     2018-01-01  1067.5  1067.5  1067.5  1067.5
# 1     2018-01-02  1066.5  1096.0  1099.0  1066.0
# 2     2018-01-03  1095.5  1088.0  1097.0  1084.0
# 3     2018-01-04  1086.5  1102.5  1108.5  1083.5
# 4     2018-01-05  1100.0  1091.5  1103.0  1086.5
# ...          ...     ...     ...     ...     ...
# 2339  2024-05-28   995.5   975.5   997.0   969.5
# 2340  2024-05-29   982.5   968.0   983.0   946.5
# 2341  2024-05-30   957.0   950.5   962.0   932.5
# 2342  2024-05-31   949.5   914.5   956.0   903.5
# 2343  2024-06-01   914.5   914.5   914.5   914.5
#
# [2344 rows x 5 columns]

# %%
df.dtypes
# Out:
# Date      object
# Open     float64
# Close    float64
# High     float64
# Low      float64
# dtype: object

# %%
df = df[["Close"]]
df.reset_index(drop=True)
# Out:
#        Close
# 0     1067.5
# 1     1096.0
# 2     1088.0
# 3     1102.5
# 4     1091.5
# ...      ...
# 2339   975.5
# 2340   968.0
# 2341   950.5
# 2342   914.5
# 2343   914.5
#
# [2344 rows x 1 columns]

# %%
df.head()
# Out:
#     Close
# 0  1067.5
# 1  1096.0
# 2  1088.0
# 3  1102.5
# 4  1091.5

# %%
#Đồ thị giá đóng
df.Close.plot(figsize = (10, 7))
plt.ylabel("Palladium price")
plt.show()

# %%
#train test split
train_size = int(0.7 * len(df))

train_df = df[:train_size]
test_df = df[train_size:]

# %%
model = ETSModel(
    train_df['Close'],
    error="mul",
    trend="add",
    seasonal="mul",
    damped_trend=False,
    seasonal_periods=90)

res = model.fit()
print(res.summary())
# Out:
#                                  ETS Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 1640
# Model:                       ETS(MAM)   Log Likelihood               -8102.408
# Date:                Thu, 13 Jun 2024   AIC                          16396.815
# Time:                        11:20:42   BIC                          16915.451
# Sample:                             0   HQIC                         16589.163
#                                - 1640   Scale                            0.000
# Covariance Type:               approx
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# smoothing_level         0.9999      0.021     47.515      0.000       0.959       1.041
# smoothing_trend         0.0029      0.007      0.432      0.666      -0.010       0.016
# smoothing_seasonal   5.242e-07        nan        nan        nan         nan         nan
# initial_level        1037.7134     95.052     10.917      0.000     851.415    1224.012
# initial_trend          -1.8936      6.337     -0.299      0.765     -14.314      10.526
# initial_seasonal.0      1.0060      0.091     11.023      0.000       0.827       1.185
# initial_seasonal.1      1.0092      0.092     11.011      0.000       0.830       1.189
# initial_seasonal.2      1.0138      0.092     10.997      0.000       0.833       1.194
# initial_seasonal.3      1.0137      0.092     10.988      0.000       0.833       1.195
# initial_seasonal.4      1.0140      0.092     10.976      0.000       0.833       1.195
# initial_seasonal.5      1.0230      0.093     10.964      0.000       0.840       1.206
# initial_seasonal.6      1.0244      0.094     10.954      0.000       0.841       1.208
# initial_seasonal.7      1.0203      0.093     10.945      0.000       0.838       1.203
# initial_seasonal.8      1.0194      0.093     10.935      0.000       0.837       1.202
# initial_seasonal.9      1.0270      0.094     10.922      0.000       0.843       1.211
# initial_seasonal.10     1.0292      0.094     10.913      0.000       0.844       1.214
# initial_seasonal.11     1.0286      0.094     10.906      0.000       0.844       1.214
# initial_seasonal.12     1.0248      0.094     10.898      0.000       0.841       1.209
# initial_seasonal.13     1.0239      0.094     10.889      0.000       0.840       1.208
# initial_seasonal.14     1.0235      0.094     10.881      0.000       0.839       1.208
# initial_seasonal.15     1.0267      0.094     10.875      0.000       0.842       1.212
# initial_seasonal.16     1.0213      0.094     10.867      0.000       0.837       1.206
# initial_seasonal.17     1.0234      0.094     10.861      0.000       0.839       1.208
# initial_seasonal.18     1.0272      0.095     10.855      0.000       0.842       1.213
# initial_seasonal.19     1.0283      0.095     10.848      0.000       0.842       1.214
# initial_seasonal.20     1.0225      0.094     10.843      0.000       0.838       1.207
# initial_seasonal.21     1.0260      0.095     10.836      0.000       0.840       1.212
# initial_seasonal.22     1.0329      0.095     10.829      0.000       0.846       1.220
# initial_seasonal.23     1.0310      0.095     10.824      0.000       0.844       1.218
# initial_seasonal.24     1.0292      0.095     10.818      0.000       0.843       1.216
# initial_seasonal.25     1.0293      0.095     10.815      0.000       0.843       1.216
# initial_seasonal.26     1.0328      0.096     10.810      0.000       0.846       1.220
# initial_seasonal.27     1.0327      0.096     10.807      0.000       0.845       1.220
# initial_seasonal.28     1.0359      0.096     10.804      0.000       0.848       1.224
# initial_seasonal.29     1.0356      0.096     10.801      0.000       0.848       1.224
# initial_seasonal.30     1.0295      0.095     10.798      0.000       0.843       1.216
# initial_seasonal.31     1.0272      0.095     10.798      0.000       0.841       1.214
# initial_seasonal.32     1.0207      0.095     10.798      0.000       0.835       1.206
# initial_seasonal.33     1.0192      0.094     10.797      0.000       0.834       1.204
# initial_seasonal.34     1.0251      0.095     10.795      0.000       0.839       1.211
# initial_seasonal.35     1.0258      0.095     10.793      0.000       0.840       1.212
# initial_seasonal.36     1.0238      0.095     10.791      0.000       0.838       1.210
# initial_seasonal.37     1.0278      0.095     10.789      0.000       0.841       1.215
# initial_seasonal.38     1.0282      0.095     10.788      0.000       0.841       1.215
# initial_seasonal.39     1.0301      0.095     10.788      0.000       0.843       1.217
# initial_seasonal.40     1.0251      0.095     10.786      0.000       0.839       1.211
# initial_seasonal.41     1.0209      0.095     10.786      0.000       0.835       1.206
# initial_seasonal.42     1.0160      0.094     10.785      0.000       0.831       1.201
# initial_seasonal.43     1.0064      0.093     10.785      0.000       0.824       1.189
# initial_seasonal.44     1.0060      0.093     10.783      0.000       0.823       1.189
# initial_seasonal.45     1.0123      0.094     10.782      0.000       0.828       1.196
# initial_seasonal.46     1.0110      0.094     10.785      0.000       0.827       1.195
# initial_seasonal.47     1.0116      0.094     10.786      0.000       0.828       1.195
# initial_seasonal.48     1.0154      0.094     10.787      0.000       0.831       1.200
# initial_seasonal.49     1.0210      0.095     10.788      0.000       0.835       1.206
# initial_seasonal.50     1.0211      0.095     10.789      0.000       0.836       1.207
# initial_seasonal.51     1.0211      0.095     10.790      0.000       0.836       1.207
# initial_seasonal.52     1.0169      0.094     10.795      0.000       0.832       1.201
# initial_seasonal.53     1.0216      0.095     10.799      0.000       0.836       1.207
# initial_seasonal.54     1.0248      0.095     10.803      0.000       0.839       1.211
# initial_seasonal.55     1.0281      0.095     10.807      0.000       0.842       1.215
# initial_seasonal.56     1.0241      0.095     10.812      0.000       0.838       1.210
# initial_seasonal.57     1.0279      0.095     10.816      0.000       0.842       1.214
# initial_seasonal.58     1.0325      0.095     10.819      0.000       0.845       1.220
# initial_seasonal.59     1.0331      0.095     10.823      0.000       0.846       1.220
# initial_seasonal.60     1.0384      0.096     10.830      0.000       0.850       1.226
# initial_seasonal.61     1.0387      0.096     10.839      0.000       0.851       1.227
# initial_seasonal.62     1.0326      0.095     10.845      0.000       0.846       1.219
# initial_seasonal.63     1.0287      0.095     10.851      0.000       0.843       1.215
# initial_seasonal.64     1.0278      0.095     10.857      0.000       0.842       1.213
# initial_seasonal.65     1.0274      0.095     10.862      0.000       0.842       1.213
# initial_seasonal.66     1.0242      0.094     10.869      0.000       0.839       1.209
# initial_seasonal.67     1.0221      0.094     10.877      0.000       0.838       1.206
# initial_seasonal.68     1.0248      0.094     10.886      0.000       0.840       1.209
# initial_seasonal.69     1.0206      0.094     10.895      0.000       0.837       1.204
# initial_seasonal.70     1.0175      0.093     10.904      0.000       0.835       1.200
# initial_seasonal.71     1.0205      0.094     10.908      0.000       0.837       1.204
# initial_seasonal.72     1.0212      0.094     10.912      0.000       0.838       1.205
# initial_seasonal.73     1.0212      0.094     10.917      0.000       0.838       1.205
# initial_seasonal.74     1.0207      0.093     10.922      0.000       0.838       1.204
# initial_seasonal.75     1.0170      0.093     10.930      0.000       0.835       1.199
# initial_seasonal.76     1.0197      0.093     10.935      0.000       0.837       1.203
# initial_seasonal.77     1.0255      0.094     10.940      0.000       0.842       1.209
# initial_seasonal.78     1.0193      0.093     10.945      0.000       0.837       1.202
# initial_seasonal.79     1.0170      0.093     10.948      0.000       0.835       1.199
# initial_seasonal.80     1.0086      0.092     10.954      0.000       0.828       1.189
# initial_seasonal.81     1.0045      0.092     10.960      0.000       0.825       1.184
# initial_seasonal.82     1.0099      0.092     10.968      0.000       0.829       1.190
# initial_seasonal.83     1.0065      0.092     10.975      0.000       0.827       1.186
# initial_seasonal.84     1.0015      0.091     10.981      0.000       0.823       1.180
# initial_seasonal.85     1.0001      0.091     10.985      0.000       0.822       1.179
# initial_seasonal.86     0.9943      0.090     11.001      0.000       0.817       1.171
# initial_seasonal.87     1.0002      0.091     11.011      0.000       0.822       1.178
# initial_seasonal.88     0.9988      0.091     11.025      0.000       0.821       1.176
# initial_seasonal.89     1.0000      0.091     11.038      0.000       0.822       1.178
# ===================================================================================
# Ljung-Box (Q):                      267.21   Jarque-Bera (JB):             15302.19
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.57   Skew:                            -0.32
# Prob(H) (two-sided):                  0.00   Kurtosis:                        17.95
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.

# %% [markdown]
# ## FORECASTING

# %%
predicted = res.predict(start = len(train_df), end = len(train_df) + len(test_df) - 1)

# %%
mape = np.mean(np.abs(predicted - test_df['Close'])/np.abs(test_df['Close'])) *100
mse = np.mean(np.square(test_df['Close'] - predicted))
rmse = np.sqrt(mse)

print("Mean Absolute Percentage Error (MAPE):", mape)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Mean Absolute Percentage Error (MAPE): 18.223596809049436
# Mean Squared Error (MSE): 64441.25450790083
# Root Mean Squared Error (RMSE): 253.85282056321697

# %%
# Quá trình tạo index predict 90 ngày tiếp theo
last_index =  df.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+90, step=1)

# Predict the closing prices for the next 90 days
y_next_90_days = res.predict(start = len(df), end = len(df) + 90 - 1)

# Print the predicted closing prices for the next 30 days
print('Predicted closing prices for the next 90 days:')
print(y_next_90_days)
# Out:
# Predicted closing prices for the next 90 days:
# 2344    1193.665656
# 2345    1194.399711
# 2346    1199.452641
# 2347    1202.558241
# 2348    1195.222948
#            ...
# 2429    1122.022794
# 2430    1114.412180
# 2431    1112.123684
# 2432    1112.826717
# 2433    1105.288954
# Length: 90, dtype: float64

# %%
predicted
# Out:
# 1640    1879.184104
# 1641    1886.115742
# 1642    1880.072906
# 1643    1882.993239
# 1644    1887.927441
#            ...
# 2339    1205.334564
# 2340    1197.227175
# 2341    1194.836911
# 2342    1195.660683
# 2343    1187.629943
# Length: 704, dtype: float64

# %%
dt_train = np.append(train_df, predicted.iloc[0])

# %%
fig, ax = plt.subplots()

plt.plot(pd.RangeIndex(start=0, stop=len(dt_train), step=1), dt_train)
plt.plot(test_df.index, test_df)
plt.plot(test_df.index, predicted)
plt.plot(last_data,y_next_90_days)
plt.plot(pd.RangeIndex(start=last_index, stop=last_index+60, step=1),y_next_90_days[0:60])
plt.plot(pd.RangeIndex(start=last_index, stop=last_index+30, step=1),y_next_90_days[0:30])
plt.legend(['Train', 'Test', 'Predictions', 'Next 90 days Predictions', 'Next 60 days Predictions', 'Next 30 days Predictions'])
plt.show()
