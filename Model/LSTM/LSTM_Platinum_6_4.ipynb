# %%
# 1. Import thư viện cần thiết
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import mean_squared_error
plt.rcParams['figure.figsize'] = [20, 8]

# %%
# 2. Đọc file csv và gắn index
df = pd.read_csv('/content/drive/MyDrive/Third Year/Sem 2/Business Data Analyst/dataset/Platinum.csv')
df = df.reset_index()['Close']
df
# Out:
# 0        930.5
# 1        945.5
# 2        957.0
# 3        964.0
# 4        969.5
#          ...
# 2339    1059.5
# 2340    1040.5
# 2341    1031.5
# 2342    1038.5
# 2343    1038.5
# Name: Close, Length: 2344, dtype: float64

# %%
# 3. Scaler data
scaler = MinMaxScaler(feature_range=(0,1))
df1 = scaler.fit_transform(np.array(df).reshape(-1,1))

# %%
# 4. Chia train test
train_size = int(0.6 * len(df1))
test_size = len(df1) - train_size

train_data = df1[:train_size]
test_data = df1[train_size:]

# %%
# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
# 8. Define LSTM Model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(100,1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 9. Fit mô hình với dữ liệu train
model.fit(X_train, y_train, validation_data = (X_test, y_test), epochs = 100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 25/25 [==============================] - 13s 232ms/step - loss: 0.0289 - val_loss: 0.0035
# Epoch 2/100
# 25/25 [==============================] - 5s 184ms/step - loss: 0.0041 - val_loss: 0.0029
# Epoch 3/100
# 25/25 [==============================] - 7s 274ms/step - loss: 0.0032 - val_loss: 0.0025
# Epoch 4/100
# 25/25 [==============================] - 4s 178ms/step - loss: 0.0035 - val_loss: 0.0024
# Epoch 5/100
# 25/25 [==============================] - 4s 179ms/step - loss: 0.0031 - val_loss: 0.0024
# Epoch 6/100
# 25/25 [==============================] - 8s 312ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 7/100
# 25/25 [==============================] - 4s 179ms/step - loss: 0.0032 - val_loss: 0.0022
# Epoch 8/100
# 25/25 [==============================] - 5s 222ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 9/100
# 25/25 [==============================] - 6s 228ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 10/100
# 25/25 [==============================] - 4s 179ms/step - loss: 0.0023 - val_loss: 0.0019
# Epoch 11/100
# 25/25 [==============================] - 6s 239ms/step - loss: 0.0022 - val_loss: 0.0019
# Epoch 12/100
# 25/25 [==============================] - 5s 205ms/step - loss: 0.0021 - val_loss: 0.0018
# Epoch 13/100
# 25/25 [==============================] - 4s 176ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 14/100
# 25/25 [==============================] - 6s 250ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 15/100
# 25/25 [==============================] - 5s 200ms/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 16/100
# 25/25 [==============================] - 4s 178ms/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 17/100
# 25/25 [==============================] - 6s 263ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 18/100
# 25/25 [==============================] - 5s 182ms/step - loss: 0.0020 - val_loss: 0.0045
# Epoch 19/100
# 25/25 [==============================] - 4s 180ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 20/100
# 25/25 [==============================] - 7s 271ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 21/100
# 25/25 [==============================] - 5s 184ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 22/100
# 25/25 [==============================] - 4s 179ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 23/100
# 25/25 [==============================] - 7s 271ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 24/100
# 25/25 [==============================] - 4s 178ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 25/100
# 25/25 [==============================] - 4s 179ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 26/100
# 25/25 [==============================] - 8s 325ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 27/100
# 25/25 [==============================] - 4s 180ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 28/100
# 25/25 [==============================] - 5s 181ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 29/100
# 25/25 [==============================] - 7s 262ms/step - loss: 0.0014 - val_loss: 9.6345e-04
# Epoch 30/100
# 25/25 [==============================] - 4s 179ms/step - loss: 0.0014 - val_loss: 9.7353e-04
# Epoch 31/100
# 25/25 [==============================] - 5s 220ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 32/100
# 25/25 [==============================] - 9s 350ms/step - loss: 0.0012 - val_loss: 8.3574e-04
# Epoch 33/100
# 25/25 [==============================] - 5s 181ms/step - loss: 0.0011 - val_loss: 8.1518e-04
# Epoch 34/100
# 25/25 [==============================] - 4s 179ms/step - loss: 0.0010 - val_loss: 8.0345e-04
# Epoch 35/100
# 25/25 [==============================] - 7s 281ms/step - loss: 0.0011 - val_loss: 8.5226e-04
# Epoch 36/100
# 25/25 [==============================] - 5s 183ms/step - loss: 0.0011 - val_loss: 7.4690e-04
# Epoch 37/100
# 25/25 [==============================] - 4s 180ms/step - loss: 9.4828e-04 - val_loss: 6.6946e-04
# Epoch 38/100
# 25/25 [==============================] - 7s 273ms/step - loss: 9.5720e-04 - val_loss: 8.6296e-04
# Epoch 39/100
# 25/25 [==============================] - 4s 180ms/step - loss: 8.8508e-04 - val_loss: 0.0010
# Epoch 40/100
# 25/25 [==============================] - 4s 179ms/step - loss: 8.9695e-04 - val_loss: 8.5735e-04
# Epoch 41/100
# 25/25 [==============================] - 7s 274ms/step - loss: 7.8845e-04 - val_loss: 5.8727e-04
# Epoch 42/100
# 25/25 [==============================] - 5s 182ms/step - loss: 7.7644e-04 - val_loss: 5.9033e-04
# Epoch 43/100
# 25/25 [==============================] - 5s 184ms/step - loss: 7.0105e-04 - val_loss: 0.0012
# Epoch 44/100
# 25/25 [==============================] - 7s 265ms/step - loss: 8.4594e-04 - val_loss: 6.0500e-04
# Epoch 45/100
# 25/25 [==============================] - 5s 182ms/step - loss: 7.1526e-04 - val_loss: 0.0056
# Epoch 46/100
# 25/25 [==============================] - 5s 192ms/step - loss: 0.0014 - val_loss: 9.9205e-04
# Epoch 47/100
# 25/25 [==============================] - 6s 257ms/step - loss: 9.4915e-04 - val_loss: 8.8961e-04
# Epoch 48/100
# 25/25 [==============================] - 5s 214ms/step - loss: 7.2419e-04 - val_loss: 7.5861e-04
# Epoch 49/100
# 25/25 [==============================] - 5s 220ms/step - loss: 7.4570e-04 - val_loss: 8.4503e-04
# Epoch 50/100
# 25/25 [==============================] - 6s 228ms/step - loss: 7.1385e-04 - val_loss: 6.3194e-04
# Epoch 51/100
# 25/25 [==============================] - 5s 180ms/step - loss: 6.5411e-04 - val_loss: 7.0012e-04
# Epoch 52/100
# 25/25 [==============================] - 5s 221ms/step - loss: 8.0255e-04 - val_loss: 4.7594e-04
# Epoch 53/100
# 25/25 [==============================] - 6s 229ms/step - loss: 5.8543e-04 - val_loss: 4.7563e-04
# Epoch 54/100
# 25/25 [==============================] - 5s 185ms/step - loss: 5.6865e-04 - val_loss: 6.3654e-04
# Epoch 55/100
# 25/25 [==============================] - 6s 230ms/step - loss: 6.0078e-04 - val_loss: 4.9102e-04
# Epoch 56/100
# 25/25 [==============================] - 6s 221ms/step - loss: 5.5873e-04 - val_loss: 9.0492e-04
# Epoch 57/100
# 25/25 [==============================] - 5s 185ms/step - loss: 7.0413e-04 - val_loss: 6.6677e-04
# Epoch 58/100
# 25/25 [==============================] - 6s 259ms/step - loss: 6.2571e-04 - val_loss: 5.1901e-04
# Epoch 59/100
# 25/25 [==============================] - 5s 181ms/step - loss: 7.5783e-04 - val_loss: 8.8938e-04
# Epoch 60/100
# 25/25 [==============================] - 4s 179ms/step - loss: 6.0741e-04 - val_loss: 4.4745e-04
# Epoch 61/100
# 25/25 [==============================] - 7s 265ms/step - loss: 5.1641e-04 - val_loss: 4.1217e-04
# Epoch 62/100
# 25/25 [==============================] - 4s 178ms/step - loss: 5.0103e-04 - val_loss: 4.6423e-04
# Epoch 63/100
# 25/25 [==============================] - 5s 181ms/step - loss: 5.2098e-04 - val_loss: 4.5800e-04
# Epoch 64/100
# 25/25 [==============================] - 7s 266ms/step - loss: 5.3401e-04 - val_loss: 8.7307e-04
# Epoch 65/100
# 25/25 [==============================] - 4s 177ms/step - loss: 5.8106e-04 - val_loss: 4.7250e-04
# Epoch 66/100
# 25/25 [==============================] - 4s 177ms/step - loss: 4.8428e-04 - val_loss: 0.0011
# Epoch 67/100
# 25/25 [==============================] - 7s 267ms/step - loss: 7.2890e-04 - val_loss: 4.1765e-04
# Epoch 68/100
# 25/25 [==============================] - 4s 180ms/step - loss: 4.8058e-04 - val_loss: 4.2961e-04
# Epoch 69/100
# 25/25 [==============================] - 4s 178ms/step - loss: 4.7656e-04 - val_loss: 3.8534e-04
# Epoch 70/100
# 25/25 [==============================] - 6s 259ms/step - loss: 5.3878e-04 - val_loss: 8.5358e-04
# Epoch 71/100
# 25/25 [==============================] - 4s 179ms/step - loss: 6.5441e-04 - val_loss: 4.9415e-04
# Epoch 72/100
# 25/25 [==============================] - 4s 180ms/step - loss: 6.9919e-04 - val_loss: 7.0697e-04
# Epoch 73/100
# 25/25 [==============================] - 7s 267ms/step - loss: 5.2882e-04 - val_loss: 4.5907e-04
# Epoch 74/100
# 25/25 [==============================] - 4s 179ms/step - loss: 5.3600e-04 - val_loss: 3.7563e-04
# Epoch 75/100
# 25/25 [==============================] - 4s 180ms/step - loss: 4.4904e-04 - val_loss: 3.7055e-04
# Epoch 76/100
# 25/25 [==============================] - 7s 273ms/step - loss: 4.6889e-04 - val_loss: 3.8987e-04
# Epoch 77/100
# 25/25 [==============================] - 5s 181ms/step - loss: 5.1181e-04 - val_loss: 3.6636e-04
# Epoch 78/100
# 25/25 [==============================] - 4s 180ms/step - loss: 4.7555e-04 - val_loss: 0.0010
# Epoch 79/100
# 25/25 [==============================] - 6s 260ms/step - loss: 6.8448e-04 - val_loss: 3.8082e-04
# Epoch 80/100
# 25/25 [==============================] - 5s 184ms/step - loss: 4.5140e-04 - val_loss: 6.0517e-04
# Epoch 81/100
# 25/25 [==============================] - 5s 188ms/step - loss: 4.5933e-04 - val_loss: 4.5102e-04
# Epoch 82/100
# 25/25 [==============================] - 7s 261ms/step - loss: 5.2439e-04 - val_loss: 8.3167e-04
# Epoch 83/100
# 25/25 [==============================] - 5s 181ms/step - loss: 6.0023e-04 - val_loss: 7.8763e-04
# Epoch 84/100
# 25/25 [==============================] - 5s 188ms/step - loss: 5.4458e-04 - val_loss: 5.0448e-04
# Epoch 85/100
# 25/25 [==============================] - 6s 257ms/step - loss: 4.6137e-04 - val_loss: 4.3983e-04
# Epoch 86/100
# 25/25 [==============================] - 5s 182ms/step - loss: 4.4136e-04 - val_loss: 7.4300e-04
# Epoch 87/100
# 25/25 [==============================] - 5s 191ms/step - loss: 5.4278e-04 - val_loss: 3.5313e-04
# Epoch 88/100
# 25/25 [==============================] - 6s 249ms/step - loss: 4.4997e-04 - val_loss: 4.2399e-04
# Epoch 89/100
# 25/25 [==============================] - 5s 183ms/step - loss: 4.3202e-04 - val_loss: 3.6011e-04
# Epoch 90/100
# 25/25 [==============================] - 5s 203ms/step - loss: 4.4687e-04 - val_loss: 7.4993e-04
# Epoch 91/100
# 25/25 [==============================] - 6s 232ms/step - loss: 5.4223e-04 - val_loss: 3.7031e-04
# Epoch 92/100
# 25/25 [==============================] - 4s 180ms/step - loss: 4.4772e-04 - val_loss: 0.0012
# Epoch 93/100
# 25/25 [==============================] - 6s 232ms/step - loss: 7.9609e-04 - val_loss: 0.0030
# Epoch 94/100
# 25/25 [==============================] - 5s 209ms/step - loss: 0.0012 - val_loss: 5.4880e-04
# Epoch 95/100
# 14/25 [===============>..............] - ETA: 1s - loss: 8.7412e-04

# %%
# 10. Dự báo dữ liệu test
y_pred = model.predict(X_test)

# %%
# 11. Chuẩn hóa dữ liệu y_pred, y_pred_val
y_pred = scaler.inverse_transform(y_pred)

# %%
train_size1 = int(0.7 * len(df))
test_size1 = len(df) - train_size

train_data1 = df[:train_size]
test_data1 = df[train_size:]

x_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

# %%
# 12. Đánh giá độ chính xác thuật toán
# Tính MSE - Mean Squared Error - Sai số bình phương trung bình
test_mse = mean_squared_error(y_test1[time_step + 1:], y_pred)
print('Testing MSE:', test_mse)

# Tính RMSE - Root Mean Squared Error - Sai số bình phương trung bình
test_rmse = math.sqrt(test_mse)
print('Testing RMSE:', test_rmse)

# Tính MAPE - Mean Absolute Percentage Error - Tỷ lệ phần trăm sai số tuyệt đối trung bình
test_mape = mean_absolute_percentage_error(y_test1[time_step + 1:], y_pred)
print('Testing MAPE:', test_mape)

# %%
# 13. Tạo hàm dự báo
def predict(n_steps, temp_input_1, x_input_1, model, day_predict):
    lst_output = []
    temp_input = temp_input_1.copy()
    x_input = x_input_1.copy()
    i = 0

    while(i < day_predict):
        if(len(temp_input) > n_steps):
            x_input=np.array(temp_input[1:])
            x_input=x_input.reshape(1,-1)
            x_input = x_input.reshape((1, n_steps, 1))
            yhat = model.predict(x_input, verbose=0)
            temp_input.extend(yhat[0].tolist())
            temp_input=temp_input[1:]
            lst_output.extend(yhat.tolist())
            i=i+1
        else:
            x_input = x_input.reshape((1, n_steps,1))
            yhat = model.predict(x_input, verbose=0)
            temp_input.extend(yhat[0].tolist())
            lst_output.extend(yhat.tolist())
            i=i+1
    return lst_output

# %%
# Dự đoán 30, 60, 90 ngày tiếp theo
n_steps = 100
x_input = test_data[len(test_data) - n_steps:].reshape(1,-1)
temp_input = list(x_input)
temp_input = temp_input[0].tolist()

lst_output_30 = predict(n_steps, temp_input, x_input, model, 30)
lst_output_60 = predict(n_steps, temp_input, x_input, model, 60)
lst_output_90 = predict(n_steps, temp_input, x_input, model, 90)

# %%
# 14.Vẽ hình
train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
plt.plot(scaler.inverse_transform(train_data))

test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index,scaler.inverse_transform(test_data))

test_data_index = pd.RangeIndex(start=train_size+101, stop=train_size+test_size, step=1)
plt.plot(test_data_index,(y_pred))

prediect_data_index = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+89, step=1)
plt.plot(prediect_data_index,scaler.inverse_transform(lst_output_90))

prediect_data_index = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+59, step=1)
plt.plot(prediect_data_index,scaler.inverse_transform(lst_output_60))

prediect_data_index = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+29, step=1)
plt.plot(prediect_data_index,scaler.inverse_transform(lst_output_30))

plt.legend(['Train','Test','Predict','Predict30days','Predict60days','Predict90days'])
plt.figure(figsize=(16,9))
plt.show()
