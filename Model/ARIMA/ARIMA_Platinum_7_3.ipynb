# %%
# Các thư viện cần thiết
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from pmdarima.arima import auto_arima
from statsmodels.tsa.stattools import adfuller
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import mean_squared_error
plt.rcParams['figure.figsize'] = [20, 8]

# %%
# Đọc file dữ liệu
df = pd.read_csv('../../Dataset/Platinum.csv')
df.shape
# Out:
# (1695, 5)

# %%
# Kiểm tra cột close có hàng nào null không
df['Close'].isnull().sum()
# Out:
# 0

# %%
# Đưa về kiểu date và đánh index
df['Date'] = pd.to_datetime(df['Date'])
df = df.set_index(['Date'])

# Sắp xếp lại index
df = df.sort_index(ascending=True)
df = df.drop(columns=['Open', 'High', 'Low'])
df
# Out:
#             Close
# Date
# 2019-03-01  860.0
# 2019-03-03  860.5
# 2019-03-04  836.5
# 2019-03-05  837.0
# 2019-03-06  827.0
# ...           ...
# 2024-03-22  897.5
# 2024-03-23  897.5
# 2024-03-24  898.0
# 2024-03-25  904.5
# 2024-03-26  904.5
#
# [1695 rows x 1 columns]

# %%
# Vẽ biểu đồ chuỗi thời gian
plt.plot(df)
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.show()

# %%
# Chia train test theo tỉ lệ
train_size = int(0.7 * len(df))
test_size = len(df) - train_size

train_data = df[:train_size]
test_data = df[train_size:]

# %%
# Chia các tập x,y train, test tương ứng
x_train = np.array(train_data.index).reshape(-1, 1)  #Lấy chỉ mục Index
y_train = np.array(train_data['Close']) #Lấy dữ liệu giá Close

x_test = np.array(test_data.index).reshape(-1, 1)  #Lấy chỉ mục Index
y_test = np.array(test_data['Close']) #Lấy dữ liệu giá Close

# %%
# Quá trình training
# Tìm kiếm các tham số tốt nhất bằng auto_arima
model = auto_arima(y_train, trace=True, error_action='ignore', suppress_warnings=True, stepwise=True)

# Fit mô hình với các tham số tốt nhất được tìm kiếm
model.fit(y_train)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=9921.151, Time=1.09 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=9920.815, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=9922.173, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=9922.163, Time=0.10 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=9918.826, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=9924.031, Time=0.29 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 1.571 seconds
# ARIMA(order=(0, 1, 0), scoring_args={}, suppress_warnings=True,
#       with_intercept=False)

# %%
# Tóm tắt model
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1186
# Model:               SARIMAX(0, 1, 0)   Log Likelihood               -4958.413
# Date:                Thu, 30 May 2024   AIC                           9918.826
# Time:                        16:29:26   BIC                           9923.904
# Sample:                             0   HQIC                          9920.740
#                                - 1186
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2       252.3352      6.228     40.515      0.000     240.128     264.542
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.64   Jarque-Bera (JB):               653.74
# Prob(Q):                              0.42   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.20   Skew:                            -0.41
# Prob(H) (two-sided):                  0.07   Kurtosis:                         6.55
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# Quá trình testing 
y_pred = model.predict(n_periods=len(x_test))

# %%
# Tính MSE - Mean Squared Error - Sai số bình phương trung bình
test_mse = mean_squared_error(y_test, y_pred) 
print('Testing MSE:', test_mse)

# Tính RMSE - Root Mean Squared Error - Sai số bình phương trung bình
test_rmse = math.sqrt(test_mse)
print('Testing RMSE:', test_rmse)

# Tính MAPE - Mean Absolute Percentage Error - Tỷ lệ phần trăm sai số tuyệt đối trung bình
test_mape = mean_absolute_percentage_error(y_test, y_pred)
print('Testing MAPE:', test_mape)
# Out:
# Testing MSE: 5527.863399017682
# Testing RMSE: 74.34960254781247
# Testing MAPE: 0.05482305898588775

# %%
# Dự đoán 30 ngày
predict_days = 30

# Quá trình tạo index predict
date_range = pd.date_range(start = df.index[-1] + pd.DateOffset(days=1), end= df.index[-1] + pd.DateOffset(days=predict_days))

# Chuyển đổi sang NumPy array và reshape
x_next = np.array(date_range).reshape(-1, 1)

# Tạo ra mảng dữ liệu dự đoán của y_next
y_next = model.predict(n_periods=len(x_next))

# In ra dữ liệu dự đoán
print('Giá Close dự đoán:')
print(y_next)

# Vẽ hình
plt.plot(x_train, y_train)
plt.plot(x_test, y_test)
plt.plot(x_test, y_pred)
plt.plot(x_next, y_next)
plt.legend(['Train', 'Test', 'Predictions', 'Next 30 days Predictions'])
plt.show()
# Out:
# Giá Close dự đoán:
# [917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917.
#  917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917.
#  917. 917.]

# %%
# Dự đoán 60 ngày
predict_days = 60

# Quá trình tạo index predict
date_range = pd.date_range(start = df.index[-1] + pd.DateOffset(days=1), end= df.index[-1] + pd.DateOffset(days=predict_days))

# Chuyển đổi sang NumPy array và reshape
x_next = np.array(date_range).reshape(-1, 1)

# Tạo ra mảng dữ liệu dự đoán của y_next
y_next = model.predict(n_periods=len(x_next))

# In ra dữ liệu dự đoán
print('Giá Close dự đoán:')
print(y_next)

# Vẽ hình
plt.plot(x_train, y_train)
plt.plot(x_test, y_test)
plt.plot(x_test, y_pred)
plt.plot(x_next, y_next)
plt.legend(['Train', 'Test', 'Predictions', 'Next 60 days Predictions'])
plt.show()
# Out:
# Giá Close dự đoán:
# [917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917.
#  917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917.
#  917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917.
#  917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917.
#  917. 917. 917. 917.]

# %%
# Dự đoán 90 ngày
predict_days = 90

# Quá trình tạo index predict
date_range = pd.date_range(start = df.index[-1] + pd.DateOffset(days=1), end= df.index[-1] + pd.DateOffset(days=predict_days))

# Chuyển đổi sang NumPy array và reshape
x_next = np.array(date_range).reshape(-1, 1)

# Tạo ra mảng dữ liệu dự đoán của y_next
y_next = model.predict(n_periods=len(x_next))

# In ra dữ liệu dự đoán
print('Giá Close dự đoán:')
print(y_next)

# Vẽ hình
plt.plot(x_train, y_train)
plt.plot(x_test, y_test)
plt.plot(x_test, y_pred)
plt.plot(x_next, y_next)
plt.legend(['Train', 'Test', 'Predictions', 'Next 90 days Predictions'])
plt.show()
# Out:
# Giá Close dự đoán:
# [917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917.
#  917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917.
#  917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917.
#  917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917.
#  917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917.
#  917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917. 917.
#  917. 917. 917. 917. 917. 917.]
